# %% [markdown]
# Install opencv

# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /home/anto/Apps/Anaconda3/lib/python3.11/site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in /home/anto/Apps/Anaconda3/lib/python3.11/site-packages (from opencv-python) (1.24.3)

# %% [markdown]
# Extracting function

# %%
import os
import cv2
import shutil
from tqdm import tqdm

def is_video_file(file_name):
    return file_name.lower().endswith('.avi')

def convert_video_to_images(video_path, output_folder, target_fps):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Get frames per second (fps) and frame count
    original_fps = int(cap.get(cv2.CAP_PROP_FPS))
    target_frame_interval = int(original_fps / target_fps)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through frames and save frames at the specified interval
    for i in tqdm(range(0, frame_count, target_frame_interval), desc=f"Converting video in {os.path.basename(output_folder)}"):
        cap.set(cv2.CAP_PROP_POS_FRAMES, i)
        ret, frame = cap.read()
        if not ret:
            break
        image_path = os.path.join(output_folder, f"frame_{i:04d}.jpg")
        cv2.imwrite(image_path, frame)

    # Release the video capture object
    cap.release()

def process_folder(input_folder, output_root, target_fps):
    # Loop through each subfolder in the input folder
    for folder_name in tqdm(os.listdir(input_folder), desc="Processing folders"):
        folder_path = os.path.join(input_folder, folder_name)
        output_folder = os.path.join(output_root, folder_name)

        # Check if the current item is a directory
        if os.path.isdir(folder_path):
            # Create the output folder if it doesn't exist
            if not os.path.exists(output_folder):
                os.makedirs(output_folder)

            # If it's the 'road view' folder, process the video files only
            if folder_name.lower() == 'road_view':
                for item in tqdm(os.listdir(folder_path), desc=f"Converting videos in {os.path.basename(output_folder)}"):
                    item_path = os.path.join(folder_path, item)
                    output_item_path = os.path.join(output_folder, os.path.splitext(item)[0])

                    # Check if the item is a video file
                    if is_video_file(item):
                        convert_video_to_images(item_path, output_item_path, target_fps)
            else:
                # If it's a driver folder, process the 'driver view' subfolder
                driver_view_path = os.path.join(folder_path, 'driver_view')

                # Check if the 'driver view' folder contains video files
                video_files = [f for f in os.listdir(driver_view_path) if is_video_file(f)]
                if video_files:
                    # Create a subfolder for each video within the driver's output folder
                    for video_file in tqdm(video_files, desc=f"Processing videos for {folder_name}"):
                        video_file_path = os.path.join(driver_view_path, video_file)
                        video_output_folder = os.path.join(output_folder, os.path.splitext(video_file)[0])
                        convert_video_to_images(video_file_path, video_output_folder, target_fps)


# Specify your input and output folders
input_folder = '/home/anto/University/Driving-Visual-Attention/data/dataset_download'
output_root = '/home/anto/University/Driving-Visual-Attention/data/images'
target_fps = 2  # Set your desired frames per second

# Process the input folder
process_folder(input_folder, output_root, target_fps)
# Out:
# Processing folders:   0%|          | 0/21 [00:00<?, ?it/s]
#
#
#
#
#
#
# Converting video in sample107: 100%|██████████| 13/13 [00:00<00:00, 17.45it/s]
#
#
#
#
#
#
#
# Converting video in sample28: 100%|██████████| 13/13 [00:00<00:00, 18.55it/s]
#
#
#
#
#
#
# Converting video in sample17: 100%|██████████| 11/11 [00:00<00:00, 19.03it/s]
#
#
#
#
# Converting video in sample66: 100%|██████████| 10/10 [00:00<00:00, 19.66it/s]
#
#
#
#
#
#
#
# Converting video in sample70: 100%|██████████| 14/14 [00:00<00:00, 18.43it/s]
#
#
#
#
#
#
# Converting video in sample53: 100%|██████████| 14/14 [00:00<00:00, 19.32it/s]
#
#
# Converting video in sample101: 100%|██████████| 4/4 [00:00<00:00, 20.34it/s]
#
#
#
#
#
# Converting video in sample47: 100%|██████████| 14/14 [00:00<00:00, 19.80it/s]
#
#
#
# Converting video in sample57: 100%|██████████| 7/7 [00:00<00:00, 19.98it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample92: 100%|██████████| 19/19 [00:01<00:00, 18.91it/s]
#
#
#
#
#
#
# Converting video in sample7: 100%|██████████| 12/12 [00:00<00:00, 19.48it/s]
#
#
#
#
#
#
#
# Converting video in sample50: 100%|██████████| 14/14 [00:00<00:00, 19.54it/s]
#
#
#
#
#
#
# Converting video in sample105: 100%|██████████| 14/14 [00:00<00:00, 18.54it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample85: 100%|██████████| 23/23 [00:01<00:00, 19.57it/s]
#
#
#
#
#
#
#
# Converting video in sample11: 100%|██████████| 16/16 [00:00<00:00, 19.72it/s]
#
#
#
#
#
# Converting video in sample4: 100%|██████████| 12/12 [00:00<00:00, 19.01it/s]
#
#
#
#
#
# Converting video in sample77: 100%|██████████| 12/12 [00:00<00:00, 20.13it/s]
#
#
#
#
#
#
# Converting video in sample97: 100%|██████████| 16/16 [00:00<00:00, 19.58it/s]
#
#
#
#
#
#
#
# Converting video in sample95: 100%|██████████| 19/19 [00:00<00:00, 20.23it/s]
#
#
#
#
#
# Converting video in sample6: 100%|██████████| 12/12 [00:00<00:00, 20.11it/s]
#
#
#
#
#
#
#
# Converting video in sample106: 100%|██████████| 18/18 [00:00<00:00, 20.89it/s]
#
#
#
#
#
# Converting video in sample5: 100%|██████████| 12/12 [00:00<00:00, 21.26it/s]
#
#
#
#
#
#
#
# Converting video in sample39: 100%|██████████| 19/19 [00:00<00:00, 21.12it/s]
#
#
#
#
# Converting video in sample51: 100%|██████████| 10/10 [00:00<00:00, 20.33it/s]
#
#
#
#
# Converting video in sample59: 100%|██████████| 9/9 [00:00<00:00, 21.72it/s]
#
#
#
#
# Converting video in sample93: 100%|██████████| 9/9 [00:00<00:00, 21.27it/s]
#
#
#
#
#
#
#
#
# Converting video in sample91: 100%|██████████| 22/22 [00:01<00:00, 21.08it/s]
#
#
#
#
#
#
#
#
# Converting video in sample38: 100%|██████████| 21/21 [00:01<00:00, 20.62it/s]
#
#
#
#
#
#
# Converting video in sample81: 100%|██████████| 16/16 [00:00<00:00, 20.94it/s]
#
#
#
#
#
#
# Converting video in sample67: 100%|██████████| 15/15 [00:00<00:00, 21.13it/s]
#
#
#
#
#
#
#
#
# Converting video in sample110: 100%|██████████| 21/21 [00:01<00:00, 20.12it/s]
#
#
#
#
#
#
# Converting video in sample22: 100%|██████████| 15/15 [00:00<00:00, 21.25it/s]
#
#
#
#
#
# Converting video in sample15: 100%|██████████| 14/14 [00:00<00:00, 21.19it/s]
#
#
#
#
#
# Converting video in sample48: 100%|██████████| 12/12 [00:00<00:00, 21.06it/s]
#
#
#
#
#
#
# Converting video in sample99: 100%|██████████| 14/14 [00:00<00:00, 18.85it/s]
#
#
#
#
#
#
#
# Converting video in sample44: 100%|██████████| 18/18 [00:00<00:00, 20.51it/s]
#
#
#
#
#
# Converting video in sample87: 100%|██████████| 14/14 [00:00<00:00, 21.16it/s]
#
#
#
#
#
#
# Converting video in sample108: 100%|██████████| 15/15 [00:00<00:00, 20.80it/s]
#
#
#
#
#
#
#
# Converting video in sample49: 100%|██████████| 19/19 [00:00<00:00, 20.41it/s]
#
#
#
#
#
# Converting video in sample37: 100%|██████████| 14/14 [00:00<00:00, 21.14it/s]
#
#
#
#
# Converting video in sample68: 100%|██████████| 9/9 [00:00<00:00, 21.04it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample65: 100%|██████████| 37/37 [00:01<00:00, 19.68it/s]
#
#
#
#
#
# Converting video in sample46: 100%|██████████| 12/12 [00:00<00:00, 20.79it/s]
#
#
#
#
#
#
#
# Converting video in sample89: 100%|██████████| 18/18 [00:00<00:00, 20.86it/s]
#
#
#
#
#
#
#
# Converting video in sample20: 100%|██████████| 20/20 [00:00<00:00, 20.47it/s]
#
#
#
#
#
#
#
# Converting video in sample21: 100%|██████████| 18/18 [00:00<00:00, 21.43it/s]
#
#
#
#
#
#
#
# Converting video in sample26: 100%|██████████| 19/19 [00:00<00:00, 20.51it/s]
#
#
#
#
#
# Converting video in sample82: 100%|██████████| 12/12 [00:00<00:00, 20.19it/s]
#
#
#
#
#
#
#
# Converting video in sample96: 100%|██████████| 18/18 [00:00<00:00, 20.65it/s]
#
#
#
#
# Converting video in sample60: 100%|██████████| 11/11 [00:00<00:00, 21.06it/s]
#
#
#
#
# Converting video in sample30: 100%|██████████| 11/11 [00:00<00:00, 21.08it/s]
#
#
#
#
#
# Converting video in sample8: 100%|██████████| 12/12 [00:00<00:00, 20.47it/s]
#
#
#
#
#
#
#
#
# Converting video in sample98: 100%|██████████| 21/21 [00:01<00:00, 20.63it/s]
#
#
#
#
#
# Converting video in sample2: 100%|██████████| 12/12 [00:00<00:00, 21.07it/s]
#
#
#
#
# Converting video in sample32: 100%|██████████| 11/11 [00:00<00:00, 20.78it/s]
#
#
#
# Converting video in sample64: 100%|██████████| 8/8 [00:00<00:00, 19.84it/s]
#
#
#
#
#
# Converting video in sample79: 100%|██████████| 12/12 [00:00<00:00, 20.74it/s]
#
#
#
#
#
# Converting video in sample23: 100%|██████████| 12/12 [00:00<00:00, 21.13it/s]
#
#
#
#
#
# Converting video in sample12: 100%|██████████| 12/12 [00:00<00:00, 21.07it/s]
#
#
#
#
#
#
#
# Converting video in sample24: 100%|██████████| 18/18 [00:00<00:00, 20.49it/s]
#
#
#
#
# Converting video in sample10: 100%|██████████| 9/9 [00:00<00:00, 21.52it/s]
#
#
#
#
#
#
# Converting video in sample54: 100%|██████████| 17/17 [00:00<00:00, 20.94it/s]
#
#
#
#
#
# Converting video in sample13: 100%|██████████| 13/13 [00:00<00:00, 21.14it/s]
#
#
#
#
#
#
# Converting video in sample100: 100%|██████████| 12/12 [00:00<00:00, 19.49it/s]
#
#
# Converting video in sample103: 100%|██████████| 4/4 [00:00<00:00, 21.96it/s]
#
#
#
#
#
#
# Converting video in sample29: 100%|██████████| 16/16 [00:00<00:00, 21.22it/s]
#
#
#
#
# Converting video in sample76: 100%|██████████| 9/9 [00:00<00:00, 20.95it/s]
#
#
#
# Converting video in sample19: 100%|██████████| 8/8 [00:00<00:00, 20.29it/s]
#
#
#
#
#
#
#
# Converting video in sample25: 100%|██████████| 19/19 [00:00<00:00, 21.20it/s]
#
#
#
#
#
#
#
#
# Converting video in sample72: 100%|██████████| 22/22 [00:01<00:00, 20.46it/s]
#
#
#
#
#
#
# Converting video in sample62: 100%|██████████| 15/15 [00:00<00:00, 20.15it/s]
#
#
#
#
#
#
# Converting video in sample80: 100%|██████████| 15/15 [00:00<00:00, 20.82it/s]
#
# Converting video in sample112: 100%|██████████| 2/2 [00:00<00:00, 22.05it/s]
#
#
# Converting video in sample102: 100%|██████████| 5/5 [00:00<00:00, 21.87it/s]
#
#
#
#
#
# Converting video in sample55: 100%|██████████| 13/13 [00:00<00:00, 21.26it/s]
#
#
#
#
#
#
#
# Converting video in sample86: 100%|██████████| 19/19 [00:00<00:00, 20.01it/s]
#
#
#
#
#
# Converting video in sample33: 100%|██████████| 13/13 [00:00<00:00, 21.16it/s]
#
#
#
#
# Converting video in sample88: 100%|██████████| 9/9 [00:00<00:00, 21.55it/s]
#
#
#
#
#
#
# Converting video in sample56: 100%|██████████| 17/17 [00:00<00:00, 21.02it/s]
#
#
#
#
#
#
#
#
# Converting video in sample27: 100%|██████████| 20/20 [00:00<00:00, 20.42it/s]
#
#
#
#
# Converting video in sample14: 100%|██████████| 11/11 [00:00<00:00, 21.53it/s]
#
#
#
#
#
#
# Converting video in sample90: 100%|██████████| 16/16 [00:00<00:00, 20.88it/s]
#
#
#
#
#
#
# Converting video in sample35: 100%|██████████| 15/15 [00:00<00:00, 20.70it/s]
#
#
#
#
#
# Converting video in sample18: 100%|██████████| 12/12 [00:00<00:00, 20.88it/s]
#
#
#
#
#
#
# Converting video in sample36: 100%|██████████| 17/17 [00:00<00:00, 20.97it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample73: 100%|██████████| 26/26 [00:01<00:00, 20.33it/s]
#
#
#
#
#
# Converting video in sample9: 100%|██████████| 12/12 [00:00<00:00, 21.07it/s]
#
#
#
#
#
#
#
# Converting video in sample71: 100%|██████████| 18/18 [00:00<00:00, 20.81it/s]
#
#
#
#
# Converting video in sample43: 100%|██████████| 10/10 [00:00<00:00, 20.83it/s]
#
#
#
#
#
#
#
# Converting video in sample111: 100%|██████████| 19/19 [00:00<00:00, 20.06it/s]
#
#
#
#
#
# Converting video in sample16: 100%|██████████| 12/12 [00:00<00:00, 20.57it/s]
#
#
#
#
#
#
#
#
# Converting video in sample42: 100%|██████████| 20/20 [00:01<00:00, 19.71it/s]
#
#
#
#
#
#
# Converting video in sample84: 100%|██████████| 13/13 [00:00<00:00, 19.41it/s]
#
#
#
#
#
# Converting video in sample63: 100%|██████████| 12/12 [00:00<00:00, 20.03it/s]
#
#
#
#
# Converting video in sample104: 100%|██████████| 9/9 [00:00<00:00, 20.84it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample52: 100%|██████████| 26/26 [00:01<00:00, 20.45it/s]
#
#
#
#
#
# Converting video in sample74: 100%|██████████| 13/13 [00:00<00:00, 20.81it/s]
#
#
#
#
#
# Converting video in sample3: 100%|██████████| 12/12 [00:00<00:00, 20.88it/s]
#
#
#
#
#
#
# Converting video in sample58: 100%|██████████| 16/16 [00:00<00:00, 19.92it/s]
#
#
#
#
#
#
#
# Converting video in sample41: 100%|██████████| 20/20 [00:00<00:00, 20.65it/s]
#
#
#
#
#
#
# Converting video in sample94: 100%|██████████| 15/15 [00:00<00:00, 20.92it/s]
#
#
#
#
#
#
#
#
# Converting video in sample109: 100%|██████████| 20/20 [00:01<00:00, 19.79it/s]
#
#
#
#
#
#
# Converting video in sample78: 100%|██████████| 17/17 [00:00<00:00, 20.78it/s]
#
#
#
#
#
# Converting video in sample45: 100%|██████████| 14/14 [00:00<00:00, 20.39it/s]
#
#
#
#
#
# Converting video in sample75: 100%|██████████| 12/12 [00:00<00:00, 20.75it/s]
#
#
#
#
#
#
#
# Converting video in sample34: 100%|██████████| 17/17 [00:00<00:00, 20.30it/s]
#
#
#
#
# Converting video in sample31: 100%|██████████| 10/10 [00:00<00:00, 21.31it/s]
#
#
#
#
#
#
#
# Converting video in sample40: 100%|██████████| 16/16 [00:00<00:00, 19.91it/s]
#
#
#
#
# Converting video in sample1: 100%|██████████| 11/11 [00:00<00:00, 20.35it/s]
#
#
#
#
#
#
#
#
# Converting video in sample83: 100%|██████████| 18/18 [00:00<00:00, 19.59it/s]
#
#
#
# Converting video in sample61: 100%|██████████| 8/8 [00:00<00:00, 21.55it/s]
#
#
#
#
#
#
# Converting video in sample69: 100%|██████████| 16/16 [00:00<00:00, 20.58it/s]
# Processing videos for driver20: 100%|██████████| 112/112 [01:20<00:00,  1.40it/s]
# Processing folders:   5%|▍         | 1/21 [01:20<26:41, 80.08s/it]
#
#
#
#
#
#
#
# Converting video in sample107: 100%|██████████| 17/17 [00:00<00:00, 19.14it/s]
#
#
#
#
#
# Converting video in sample28: 100%|██████████| 13/13 [00:00<00:00, 19.91it/s]
#
#
#
#
# Converting video in sample17: 100%|██████████| 11/11 [00:00<00:00, 20.16it/s]
#
#
#
#
#
# Converting video in sample66: 100%|██████████| 12/12 [00:00<00:00, 18.50it/s]
#
#
#
#
#
#
#
#
# Converting video in sample70: 100%|██████████| 15/15 [00:00<00:00, 19.06it/s]
#
#
#
#
#
#
# Converting video in sample53: 100%|██████████| 14/14 [00:00<00:00, 19.47it/s]
#
#
#
#
#
# Converting video in sample101: 100%|██████████| 11/11 [00:00<00:00, 19.85it/s]
#
#
#
#
#
#
#
# Converting video in sample47: 100%|██████████| 15/15 [00:00<00:00, 19.19it/s]
#
#
#
# Converting video in sample57: 100%|██████████| 7/7 [00:00<00:00, 20.26it/s]
#
#
#
#
#
#
#
#
# Converting video in sample92: 100%|██████████| 18/18 [00:00<00:00, 19.67it/s]
#
#
#
#
#
# Converting video in sample7: 100%|██████████| 11/11 [00:00<00:00, 19.11it/s]
#
#
#
#
#
#
#
# Converting video in sample50: 100%|██████████| 14/14 [00:00<00:00, 19.22it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample105: 100%|██████████| 23/23 [00:01<00:00, 19.17it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample85: 100%|██████████| 22/22 [00:01<00:00, 18.98it/s]
#
#
#
#
#
#
#
# Converting video in sample11: 100%|██████████| 16/16 [00:00<00:00, 19.56it/s]
#
#
#
# Converting video in sample4: 100%|██████████| 8/8 [00:00<00:00, 19.16it/s]
#
#
#
#
#
# Converting video in sample77: 100%|██████████| 13/13 [00:00<00:00, 20.31it/s]
#
#
#
#
#
#
#
#
# Converting video in sample97: 100%|██████████| 15/15 [00:00<00:00, 15.86it/s]
#
#
#
#
#
#
#
# Converting video in sample95: 100%|██████████| 19/19 [00:00<00:00, 20.37it/s]
#
#
#
#
#
# Converting video in sample6: 100%|██████████| 12/12 [00:00<00:00, 21.81it/s]
#
#
#
#
#
#
#
#
# Converting video in sample106: 100%|██████████| 23/23 [00:01<00:00, 21.35it/s]
#
#
#
#
#
# Converting video in sample5: 100%|██████████| 13/13 [00:00<00:00, 20.93it/s]
#
#
#
#
#
#
#
# Converting video in sample39: 100%|██████████| 19/19 [00:00<00:00, 20.27it/s]
#
#
#
#
#
#
# Converting video in sample51: 100%|██████████| 16/16 [00:00<00:00, 21.48it/s]
#
#
#
#
# Converting video in sample59: 100%|██████████| 10/10 [00:00<00:00, 20.26it/s]
#
#
#
#
# Converting video in sample93: 100%|██████████| 9/9 [00:00<00:00, 21.70it/s]
#
#
#
#
#
#
#
#
# Converting video in sample91: 100%|██████████| 21/21 [00:00<00:00, 21.02it/s]
#
#
#
#
#
#
#
#
# Converting video in sample38: 100%|██████████| 22/22 [00:01<00:00, 19.86it/s]
#
#
#
#
#
#
# Converting video in sample81: 100%|██████████| 16/16 [00:00<00:00, 21.12it/s]
#
#
#
#
#
#
# Converting video in sample67: 100%|██████████| 16/16 [00:00<00:00, 21.37it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample110: 100%|██████████| 27/27 [00:01<00:00, 21.02it/s]
#
#
#
#
#
#
# Converting video in sample22: 100%|██████████| 16/16 [00:00<00:00, 21.35it/s]
#
#
#
#
#
# Converting video in sample15: 100%|██████████| 14/14 [00:00<00:00, 19.79it/s]
#
#
#
#
#
#
#
# Converting video in sample48: 100%|██████████| 12/12 [00:00<00:00, 18.88it/s]
#
#
#
#
#
#
# Converting video in sample99: 100%|██████████| 14/14 [00:00<00:00, 19.56it/s]
#
#
#
#
#
#
#
#
# Converting video in sample44: 100%|██████████| 19/19 [00:00<00:00, 19.03it/s]
#
#
#
#
#
#
# Converting video in sample87: 100%|██████████| 15/15 [00:00<00:00, 19.97it/s]
#
#
#
#
#
#
#
# Converting video in sample108: 100%|██████████| 18/18 [00:00<00:00, 19.64it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample49: 100%|██████████| 20/20 [00:01<00:00, 18.60it/s]
#
#
#
#
#
#
#
# Converting video in sample37: 100%|██████████| 14/14 [00:00<00:00, 19.53it/s]
#
#
#
#
# Converting video in sample68: 100%|██████████| 10/10 [00:00<00:00, 19.95it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample65: 100%|██████████| 37/37 [00:01<00:00, 19.05it/s]
#
#
#
#
#
# Converting video in sample46: 100%|██████████| 12/12 [00:00<00:00, 18.89it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample89: 100%|██████████| 24/24 [00:01<00:00, 19.51it/s]
#
#
#
#
#
#
#
# Converting video in sample20: 100%|██████████| 20/20 [00:00<00:00, 20.53it/s]
#
#
#
#
#
#
#
# Converting video in sample21: 100%|██████████| 18/18 [00:00<00:00, 21.25it/s]
#
#
#
#
#
#
#
# Converting video in sample26: 100%|██████████| 19/19 [00:00<00:00, 21.22it/s]
#
#
#
#
# Converting video in sample82: 100%|██████████| 11/11 [00:00<00:00, 20.88it/s]
#
#
#
#
#
#
# Converting video in sample96: 100%|██████████| 17/17 [00:00<00:00, 21.47it/s]
#
#
#
#
# Converting video in sample60: 100%|██████████| 11/11 [00:00<00:00, 21.42it/s]
#
#
#
#
#
#
# Converting video in sample30: 100%|██████████| 12/12 [00:00<00:00, 18.89it/s]
#
#
#
#
#
# Converting video in sample8: 100%|██████████| 12/12 [00:00<00:00, 21.42it/s]
#
#
#
#
#
#
#
# Converting video in sample98: 100%|██████████| 20/20 [00:00<00:00, 21.24it/s]
#
#
#
#
#
# Converting video in sample2: 100%|██████████| 12/12 [00:00<00:00, 20.61it/s]
#
#
#
#
# Converting video in sample32: 100%|██████████| 11/11 [00:00<00:00, 21.44it/s]
#
#
#
#
# Converting video in sample64: 100%|██████████| 9/9 [00:00<00:00, 21.34it/s]
#
#
#
#
#
# Converting video in sample79: 100%|██████████| 12/12 [00:00<00:00, 21.71it/s]
#
#
#
#
#
# Converting video in sample23: 100%|██████████| 12/12 [00:00<00:00, 20.58it/s]
#
#
#
#
#
# Converting video in sample12: 100%|██████████| 13/13 [00:00<00:00, 21.79it/s]
#
#
#
#
#
#
#
# Converting video in sample24: 100%|██████████| 18/18 [00:00<00:00, 20.52it/s]
#
#
#
#
# Converting video in sample10: 100%|██████████| 9/9 [00:00<00:00, 18.57it/s]
#
#
#
#
#
#
#
# Converting video in sample54: 100%|██████████| 17/17 [00:00<00:00, 20.20it/s]
#
#
#
#
#
# Converting video in sample13: 100%|██████████| 13/13 [00:00<00:00, 22.69it/s]
#
#
#
#
#
#
#
# Converting video in sample100: 100%|██████████| 18/18 [00:00<00:00, 21.69it/s]
#
#
#
#
# Converting video in sample103: 100%|██████████| 9/9 [00:00<00:00, 22.91it/s]
#
#
#
#
#
#
# Converting video in sample29: 100%|██████████| 15/15 [00:00<00:00, 22.56it/s]
#
#
#
#
# Converting video in sample76: 100%|██████████| 10/10 [00:00<00:00, 21.78it/s]
#
#
#
# Converting video in sample19: 100%|██████████| 8/8 [00:00<00:00, 22.86it/s]
#
#
#
#
#
#
#
# Converting video in sample25: 100%|██████████| 18/18 [00:00<00:00, 22.21it/s]
#
#
#
#
#
#
#
#
# Converting video in sample72: 100%|██████████| 21/21 [00:00<00:00, 21.77it/s]
#
#
#
#
#
#
# Converting video in sample62: 100%|██████████| 16/16 [00:00<00:00, 22.49it/s]
#
#
#
#
#
#
# Converting video in sample80: 100%|██████████| 15/15 [00:00<00:00, 22.34it/s]
#
#
#
# Converting video in sample112: 100%|██████████| 6/6 [00:00<00:00, 22.75it/s]
#
#
#
#
#
# Converting video in sample102: 100%|██████████| 14/14 [00:00<00:00, 21.80it/s]
#
#
#
#
#
# Converting video in sample55: 100%|██████████| 13/13 [00:00<00:00, 22.45it/s]
#
#
#
#
#
#
#
# Converting video in sample86: 100%|██████████| 19/19 [00:00<00:00, 22.40it/s]
#
#
#
#
#
# Converting video in sample33: 100%|██████████| 13/13 [00:00<00:00, 21.76it/s]
#
#
#
#
# Converting video in sample88: 100%|██████████| 9/9 [00:00<00:00, 23.37it/s]
#
#
#
#
#
#
# Converting video in sample56: 100%|██████████| 17/17 [00:00<00:00, 20.25it/s]
#
#
#
#
#
#
#
#
# Converting video in sample27: 100%|██████████| 20/20 [00:01<00:00, 18.94it/s]
#
#
#
#
#
#
#
# Converting video in sample14: 100%|██████████| 12/12 [00:00<00:00, 15.09it/s]
#
#
#
#
#
#
#
#
# Converting video in sample90: 100%|██████████| 16/16 [00:00<00:00, 16.18it/s]
#
#
#
#
#
#
#
# Converting video in sample35: 100%|██████████| 15/15 [00:00<00:00, 16.42it/s]
#
#
#
#
#
# Converting video in sample18: 100%|██████████| 13/13 [00:00<00:00, 21.69it/s]
#
#
#
#
#
#
#
# Converting video in sample36: 100%|██████████| 17/17 [00:00<00:00, 17.79it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample73: 100%|██████████| 27/27 [00:01<00:00, 15.60it/s]
#
#
#
#
#
#
#
# Converting video in sample9: 100%|██████████| 12/12 [00:00<00:00, 13.76it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample71: 100%|██████████| 19/19 [00:01<00:00, 14.21it/s]
#
#
#
#
#
#
# Converting video in sample43: 100%|██████████| 11/11 [00:00<00:00, 15.20it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample111: 100%|██████████| 22/22 [00:01<00:00, 15.52it/s]
#
#
#
#
#
#
#
# Converting video in sample16: 100%|██████████| 12/12 [00:00<00:00, 16.02it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample42: 100%|██████████| 22/22 [00:01<00:00, 15.41it/s]
#
#
#
#
#
#
#
# Converting video in sample84: 100%|██████████| 13/13 [00:00<00:00, 16.79it/s]
#
#
#
#
#
#
#
# Converting video in sample63: 100%|██████████| 13/13 [00:00<00:00, 16.49it/s]
#
#
#
#
#
#
#
#
# Converting video in sample104: 100%|██████████| 15/15 [00:00<00:00, 16.96it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample52: 100%|██████████| 26/26 [00:01<00:00, 16.77it/s]
#
#
#
#
#
#
#
#
# Converting video in sample74: 100%|██████████| 14/14 [00:00<00:00, 16.44it/s]
#
#
#
#
#
#
# Converting video in sample3: 100%|██████████| 11/11 [00:00<00:00, 16.08it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample58: 100%|██████████| 16/16 [00:00<00:00, 17.92it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample41: 100%|██████████| 21/21 [00:01<00:00, 16.87it/s]
#
#
#
#
#
#
#
# Converting video in sample94: 100%|██████████| 15/15 [00:00<00:00, 19.16it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample109: 100%|██████████| 25/25 [00:01<00:00, 19.33it/s]
#
#
#
#
#
#
#
# Converting video in sample78: 100%|██████████| 18/18 [00:00<00:00, 20.10it/s]
#
#
#
#
#
#
#
# Converting video in sample45: 100%|██████████| 15/15 [00:00<00:00, 19.09it/s]
#
#
#
#
#
# Converting video in sample75: 100%|██████████| 12/12 [00:00<00:00, 20.12it/s]
#
#
#
#
#
#
#
# Converting video in sample34: 100%|██████████| 18/18 [00:00<00:00, 20.21it/s]
#
#
#
#
#
#
# Converting video in sample31: 100%|██████████| 10/10 [00:00<00:00, 17.03it/s]
#
#
#
#
#
#
# Converting video in sample40: 100%|██████████| 17/17 [00:00<00:00, 20.96it/s]
#
#
#
#
#
# Converting video in sample1: 100%|██████████| 12/12 [00:00<00:00, 20.31it/s]
#
#
#
# Converting video in sample83: 100%|██████████| 5/5 [00:00<00:00, 15.51it/s]
#
#
#
#
# Converting video in sample61: 100%|██████████| 8/8 [00:00<00:00, 19.69it/s]
#
#
#
#
#
#
# Converting video in sample69: 100%|██████████| 17/17 [00:00<00:00, 20.52it/s]
# Processing videos for driver22: 100%|██████████| 112/112 [01:29<00:00,  1.26it/s]
# Processing folders:  10%|▉         | 2/21 [02:49<27:02, 85.40s/it]
#
#
#
#
#
#
# Converting video in sample107: 100%|██████████| 11/11 [00:00<00:00, 15.44it/s]
#
#
#
#
#
#
# Converting video in sample28: 100%|██████████| 10/10 [00:00<00:00, 17.52it/s]
#
#
#
#
# Converting video in sample17: 100%|██████████| 8/8 [00:00<00:00, 19.75it/s]
#
#
#
#
# Converting video in sample66: 100%|██████████| 8/8 [00:00<00:00, 18.80it/s]
#
#
#
#
#
# Converting video in sample70: 100%|██████████| 10/10 [00:00<00:00, 16.92it/s]
#
#
#
#
#
# Converting video in sample53: 100%|██████████| 9/9 [00:00<00:00, 16.76it/s]
#
#
#
# Converting video in sample101: 100%|██████████| 7/7 [00:00<00:00, 19.09it/s]
#
#
#
#
# Converting video in sample47: 100%|██████████| 7/7 [00:00<00:00, 19.56it/s]
#
#
# Converting video in sample57: 100%|██████████| 5/5 [00:00<00:00, 20.47it/s]
#
#
#
#
#
#
#
# Converting video in sample92: 100%|██████████| 13/13 [00:00<00:00, 16.16it/s]
#
#
#
#
#
# Converting video in sample7: 100%|██████████| 9/9 [00:00<00:00, 16.94it/s]
#
#
#
#
# Converting video in sample50: 100%|██████████| 9/9 [00:00<00:00, 19.89it/s]
#
#
#
#
#
#
#
# Converting video in sample105: 100%|██████████| 16/16 [00:00<00:00, 17.68it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample85: 100%|██████████| 15/15 [00:00<00:00, 16.78it/s]
#
#
#
#
#
# Converting video in sample11: 100%|██████████| 12/12 [00:00<00:00, 18.68it/s]
#
#
#
#
#
# Converting video in sample4: 100%|██████████| 10/10 [00:00<00:00, 16.48it/s]
#
#
#
# Converting video in sample77: 100%|██████████| 4/4 [00:00<00:00, 16.08it/s]
#
#
#
#
#
# Converting video in sample97: 100%|██████████| 9/9 [00:00<00:00, 17.66it/s]
#
#
#
#
#
#
# Converting video in sample95: 100%|██████████| 11/11 [00:00<00:00, 18.03it/s]
#
#
#
#
# Converting video in sample6: 100%|██████████| 9/9 [00:00<00:00, 16.87it/s]
#
#
#
#
#
#
#
# Converting video in sample106: 100%|██████████| 15/15 [00:00<00:00, 17.39it/s]
#
#
#
#
# Converting video in sample5: 100%|██████████| 9/9 [00:00<00:00, 18.60it/s]
#
#
#
#
#
# Converting video in sample39: 100%|██████████| 11/11 [00:00<00:00, 16.52it/s]
#
#
#
#
#
#
# Converting video in sample51: 100%|██████████| 10/10 [00:00<00:00, 16.87it/s]
#
#
#
# Converting video in sample59: 100%|██████████| 7/7 [00:00<00:00, 18.53it/s]
#
#
#
# Converting video in sample93: 100%|██████████| 6/6 [00:00<00:00, 20.86it/s]
#
#
#
#
#
# Converting video in sample91: 100%|██████████| 13/13 [00:00<00:00, 20.99it/s]
#
#
#
#
#
# Converting video in sample38: 100%|██████████| 13/13 [00:00<00:00, 20.76it/s]
#
#
#
#
#
# Converting video in sample81: 100%|██████████| 11/11 [00:00<00:00, 20.31it/s]
#
#
#
#
# Converting video in sample67: 100%|██████████| 9/9 [00:00<00:00, 21.36it/s]
#
#
#
#
#
#
# Converting video in sample110: 100%|██████████| 16/16 [00:00<00:00, 20.32it/s]
#
#
#
#
#
#
# Converting video in sample22: 100%|██████████| 12/12 [00:00<00:00, 17.23it/s]
#
#
#
#
# Converting video in sample15: 100%|██████████| 10/10 [00:00<00:00, 19.83it/s]
#
#
#
#
# Converting video in sample48: 100%|██████████| 8/8 [00:00<00:00, 18.70it/s]
#
#
#
# Converting video in sample99: 100%|██████████| 8/8 [00:00<00:00, 19.70it/s]
#
#
#
#
#
# Converting video in sample44: 100%|██████████| 12/12 [00:00<00:00, 20.77it/s]
#
#
#
#
# Converting video in sample87: 100%|██████████| 9/9 [00:00<00:00, 20.40it/s]
#
#
#
#
# Converting video in sample108: 100%|██████████| 9/9 [00:00<00:00, 21.37it/s]
#
#
#
#
#
# Converting video in sample49: 100%|██████████| 13/13 [00:00<00:00, 20.18it/s]
#
#
#
# Converting video in sample37: 100%|██████████| 8/8 [00:00<00:00, 20.98it/s]
#
#
#
# Converting video in sample68: 100%|██████████| 6/6 [00:00<00:00, 19.66it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample65: 100%|██████████| 24/24 [00:01<00:00, 19.78it/s]
#
#
#
# Converting video in sample46: 100%|██████████| 8/8 [00:00<00:00, 21.42it/s]
#
#
#
#
#
#
# Converting video in sample89: 100%|██████████| 16/16 [00:00<00:00, 21.13it/s]
#
#
#
#
#
#
# Converting video in sample20: 100%|██████████| 14/14 [00:00<00:00, 19.70it/s]
#
#
#
#
#
# Converting video in sample21: 100%|██████████| 12/12 [00:00<00:00, 21.68it/s]
#
#
#
#
#
# Converting video in sample26: 100%|██████████| 14/14 [00:00<00:00, 21.63it/s]
#
#
#
#
# Converting video in sample82: 100%|██████████| 8/8 [00:00<00:00, 20.17it/s]
#
#
#
# Converting video in sample96: 100%|██████████| 7/7 [00:00<00:00, 21.47it/s]
#
#
#
# Converting video in sample60: 100%|██████████| 7/7 [00:00<00:00, 21.38it/s]
#
#
#
# Converting video in sample30: 100%|██████████| 8/8 [00:00<00:00, 21.02it/s]
#
#
#
#
#
# Converting video in sample8: 100%|██████████| 9/9 [00:00<00:00, 18.64it/s]
#
#
#
#
#
#
# Converting video in sample98: 100%|██████████| 13/13 [00:00<00:00, 19.63it/s]
#
#
#
#
# Converting video in sample2: 100%|██████████| 10/10 [00:00<00:00, 20.95it/s]
#
#
#
#
# Converting video in sample32: 100%|██████████| 8/8 [00:00<00:00, 19.37it/s]
#
#
# Converting video in sample64: 100%|██████████| 4/4 [00:00<00:00, 19.92it/s]
#
#
#
#
#
# Converting video in sample79: 100%|██████████| 8/8 [00:00<00:00, 14.88it/s]
#
#
#
#
#
# Converting video in sample23: 100%|██████████| 9/9 [00:00<00:00, 12.84it/s]
#
#
#
#
#
# Converting video in sample12: 100%|██████████| 9/9 [00:00<00:00, 17.23it/s]
#
#
#
#
#
#
# Converting video in sample24: 100%|██████████| 14/14 [00:00<00:00, 19.99it/s]
#
#
#
# Converting video in sample10: 100%|██████████| 7/7 [00:00<00:00, 19.32it/s]
#
#
#
#
# Converting video in sample54: 100%|██████████| 10/10 [00:00<00:00, 20.80it/s]
#
#
#
#
#
#
# Converting video in sample13: 100%|██████████| 10/10 [00:00<00:00, 17.81it/s]
#
#
#
#
#
#
# Converting video in sample100: 100%|██████████| 11/11 [00:00<00:00, 16.07it/s]
#
#
#
# Converting video in sample103: 100%|██████████| 6/6 [00:00<00:00, 18.44it/s]
#
#
#
#
#
# Converting video in sample29: 100%|██████████| 11/11 [00:00<00:00, 15.62it/s]
#
#
#
#
# Converting video in sample76: 100%|██████████| 6/6 [00:00<00:00, 10.82it/s]
#
#
#
#
# Converting video in sample19: 100%|██████████| 6/6 [00:00<00:00, 10.69it/s]
#
#
#
#
#
#
#
# Converting video in sample25: 100%|██████████| 14/14 [00:00<00:00, 19.03it/s]
#
#
#
#
#
#
#
# Converting video in sample72: 100%|██████████| 12/12 [00:00<00:00, 12.09it/s]
#
#
#
#
#
#
# Converting video in sample62: 100%|██████████| 10/10 [00:00<00:00, 17.33it/s]
#
#
#
#
#
# Converting video in sample80: 100%|██████████| 10/10 [00:00<00:00, 18.20it/s]
#
#
#
#
#
# Converting video in sample112: 100%|██████████| 10/10 [00:00<00:00, 18.67it/s]
#
#
#
#
# Converting video in sample102: 100%|██████████| 8/8 [00:00<00:00, 19.32it/s]
#
#
#
#
# Converting video in sample55: 100%|██████████| 9/9 [00:00<00:00, 18.86it/s]
#
#
#
#
#
#
#
# Converting video in sample86: 100%|██████████| 13/13 [00:00<00:00, 17.97it/s]
#
#
#
#
# Converting video in sample33: 100%|██████████| 9/9 [00:00<00:00, 19.54it/s]
#
#
#
#
# Converting video in sample88: 100%|██████████| 6/6 [00:00<00:00, 18.02it/s]
#
#
#
#
# Converting video in sample56: 100%|██████████| 9/9 [00:00<00:00, 20.49it/s]
#
#
#
#
#
#
# Converting video in sample27: 100%|██████████| 15/15 [00:00<00:00, 20.46it/s]
#
#
#
#
# Converting video in sample14: 100%|██████████| 8/8 [00:00<00:00, 18.42it/s]
#
#
#
#
# Converting video in sample90: 100%|██████████| 11/11 [00:00<00:00, 20.43it/s]
#
#
#
#
# Converting video in sample35: 100%|██████████| 9/9 [00:00<00:00, 19.75it/s]
#
#
#
#
# Converting video in sample18: 100%|██████████| 9/9 [00:00<00:00, 19.25it/s]
#
#
#
#
# Converting video in sample36: 100%|██████████| 11/11 [00:00<00:00, 20.49it/s]
#
#
#
#
#
#
#
#
# Converting video in sample73: 100%|██████████| 16/16 [00:01<00:00, 15.23it/s]
#
#
#
#
#
# Converting video in sample9: 100%|██████████| 8/8 [00:00<00:00, 14.27it/s]
#
#
#
#
#
#
#
# Converting video in sample71: 100%|██████████| 12/12 [00:00<00:00, 16.96it/s]
#
#
#
#
# Converting video in sample43: 100%|██████████| 7/7 [00:00<00:00, 17.27it/s]
#
#
#
#
#
#
#
#
# Converting video in sample111: 100%|██████████| 14/14 [00:00<00:00, 15.64it/s]
#
#
#
#
#
# Converting video in sample16: 100%|██████████| 8/8 [00:00<00:00, 17.06it/s]
#
#
#
#
#
#
#
#
# Converting video in sample42: 100%|██████████| 14/14 [00:00<00:00, 15.95it/s]
#
#
#
#
# Converting video in sample84: 100%|██████████| 8/8 [00:00<00:00, 19.40it/s]
#
#
#
#
# Converting video in sample63: 100%|██████████| 8/8 [00:00<00:00, 18.29it/s]
#
#
#
#
#
#
# Converting video in sample104: 100%|██████████| 11/11 [00:00<00:00, 16.32it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample52: 100%|██████████| 18/18 [00:01<00:00, 17.69it/s]
#
#
#
#
#
# Converting video in sample74: 100%|██████████| 9/9 [00:00<00:00, 15.82it/s]
#
#
#
#
#
#
# Converting video in sample3: 100%|██████████| 11/11 [00:00<00:00, 18.75it/s]
#
#
#
#
# Converting video in sample58: 100%|██████████| 9/9 [00:00<00:00, 18.61it/s]
#
#
#
#
#
#
#
#
# Converting video in sample41: 100%|██████████| 14/14 [00:00<00:00, 17.63it/s]
#
#
#
#
#
#
# Converting video in sample113: 100%|██████████| 10/10 [00:00<00:00, 17.38it/s]
#
#
#
#
#
#
# Converting video in sample94: 100%|██████████| 10/10 [00:00<00:00, 17.12it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample109: 100%|██████████| 16/16 [00:00<00:00, 17.72it/s]
#
#
#
#
#
#
#
# Converting video in sample78: 100%|██████████| 12/12 [00:00<00:00, 15.83it/s]
#
#
#
#
#
#
# Converting video in sample45: 100%|██████████| 10/10 [00:00<00:00, 17.86it/s]
#
#
#
#
# Converting video in sample75: 100%|██████████| 7/7 [00:00<00:00, 16.36it/s]
#
#
#
#
#
#
#
# Converting video in sample34: 100%|██████████| 12/12 [00:00<00:00, 17.04it/s]
#
#
#
#
# Converting video in sample31: 100%|██████████| 7/7 [00:00<00:00, 18.37it/s]
#
#
#
#
#
#
# Converting video in sample40: 100%|██████████| 11/11 [00:00<00:00, 17.45it/s]
#
#
#
#
#
# Converting video in sample1: 100%|██████████| 11/11 [00:00<00:00, 19.49it/s]
#
#
#
#
#
#
# Converting video in sample83: 100%|██████████| 11/11 [00:00<00:00, 17.27it/s]
#
#
#
# Converting video in sample61: 100%|██████████| 5/5 [00:00<00:00, 18.62it/s]
#
#
#
#
#
#
# Converting video in sample69: 100%|██████████| 10/10 [00:00<00:00, 17.19it/s]
# Processing videos for driver21: 100%|██████████| 113/113 [01:04<00:00,  1.76it/s]
# Processing folders:  14%|█▍        | 3/21 [03:53<22:44, 75.79s/it]
#
#
#
#
#
# Converting video in trip70_out_hist:   4%|▍         | 9/205 [00:00<00:17, 11.53it/s]
#
#
#
#
#
#
# Converting video in trip54_out_hist:   4%|▍         | 11/245 [00:01<00:22, 10.63it/s]
#
#
#
#
#
# Converting video in trip13_out_hist:   5%|▍         | 8/177 [00:00<00:14, 11.42it/s]
#
#
#
#
#
# Converting video in trip55_out_hist:   4%|▍         | 8/183 [00:00<00:17, 10.13it/s]
#
#
#
#
# Converting video in trip82_out_hist:   4%|▍         | 7/159 [00:00<00:12, 11.95it/s]
#
#
#
#
# Converting video in trip43_out_hist:   4%|▍         | 6/139 [00:00<00:13, 10.15it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip92_out_hist: 100%|██████████| 12/12 [00:01<00:00,  8.86it/s]
#
#
#
#
#
#
#
# Converting video in trip78_out_hist:   5%|▍         | 12/265 [00:01<00:24, 10.26it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in trip52_out_hist:   4%|▍         | 18/409 [00:01<00:33, 11.69it/s]
#
#
#
#
#
#
# Converting video in trip102_out_hist: 100%|██████████| 8/8 [00:00<00:00,  9.67it/s]
#
#
#
#
#
#
# Converting video in trip80_out_hist:   4%|▍         | 10/225 [00:00<00:20, 10.47it/s]
#
#
#
#
#
# Converting video in trip74_out_hist:   4%|▍         | 8/185 [00:00<00:17, 10.26it/s]
#
#
#
#
#
#
# Converting video in trip69_out_hist:   4%|▍         | 11/247 [00:01<00:21, 10.95it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in trip22_out_hist:   4%|▍         | 10/229 [00:01<00:24,  8.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip109_out_hist: 100%|██████████| 17/17 [00:01<00:00,  9.70it/s]
#
#
#
#
#
#
#
# Converting video in trip49_out_hist:   4%|▍         | 13/305 [00:01<00:25, 11.46it/s]
#
#
#
# Converting video in trip57_out_hist:   5%|▍         | 4/83 [00:00<00:06, 12.49it/s]
#
#
#
#
#
#
# Converting video in trip58_out_hist:   4%|▍         | 10/235 [00:00<00:19, 11.29it/s]
#
#
#
#
# Converting video in trip14_out_hist:   5%|▍         | 7/153 [00:00<00:11, 12.23it/s]
#
#
#
#
#
#
#
# Converting video in trip21_out_hist:   5%|▍         | 12/265 [00:01<00:23, 10.82it/s]
#
#
#
#
#
#
#
# Converting video in trip95_out_hist: 100%|██████████| 13/13 [00:01<00:00, 10.22it/s]
#
#
#
# Converting video in trip61_out_hist:   4%|▍         | 4/89 [00:00<00:08, 10.33it/s]
#
#
#
#
#
# Converting video in trip53_out_hist:   4%|▍         | 9/205 [00:00<00:18, 10.75it/s]
#
#
#
#
# Converting video in trip6_out_hist: 100%|██████████| 9/9 [00:00<00:00, 20.58it/s]
#
#
#
#
# Converting video in trip17_out_hist:   4%|▍         | 6/139 [00:00<00:12, 10.89it/s]
#
#
#
#
#
# Converting video in trip87_out_hist: 100%|██████████| 9/9 [00:00<00:00, 10.97it/s]
#
#
#
#
#
#
# Converting video in trip46_out_hist:   5%|▍         | 8/171 [00:00<00:19,  8.50it/s]
#
#
#
#
#
#
#
#
#
# Converting video in trip99_out_hist: 100%|██████████| 9/9 [00:01<00:00,  8.85it/s]
#
#
#
#
# Converting video in trip60_out_hist:   4%|▍         | 6/135 [00:00<00:12, 10.34it/s]
#
#
#
#
#
#
#
#
#
# Converting video in trip37_out_hist:   4%|▍         | 8/187 [00:01<00:23,  7.58it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in trip26_out_hist:   4%|▍         | 12/281 [00:01<00:30,  8.92it/s]
#
#
#
#
#
# Converting video in trip47_out_hist:   4%|▍         | 9/207 [00:00<00:18, 10.42it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip106_out_hist: 100%|██████████| 16/16 [00:01<00:00,  9.14it/s]
#
#
#
#
# Converting video in trip19_out_hist:   5%|▌         | 5/97 [00:00<00:09,  9.40it/s]
#
#
#
#
#
#
#
# Converting video in trip24_out_hist:   5%|▍         | 12/265 [00:01<00:25,  9.96it/s]
#
#
#
#
#
# Converting video in trip8_out_hist: 100%|██████████| 9/9 [00:00<00:00, 15.29it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip39_out_hist:   4%|▍         | 12/279 [00:01<00:30,  8.68it/s]
#
#
#
#
#
# Converting video in trip35_out_hist:   4%|▍         | 9/213 [00:00<00:21,  9.69it/s]
#
#
#
#
#
#
# Converting video in trip51_out_hist:   4%|▍         | 10/223 [00:01<00:22,  9.66it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip110_out_hist: 100%|██████████| 18/18 [00:01<00:00,  9.33it/s]
#
#
#
# Converting video in trip76_out_hist:   4%|▍         | 5/117 [00:00<00:10, 11.15it/s]
#
#
#
#
#
#
#
#
# Converting video in trip112_out_hist: 100%|██████████| 15/15 [00:01<00:00, 10.38it/s]
#
#
#
#
#
#
#
#
# Converting video in trip107_out_hist: 100%|██████████| 11/11 [00:01<00:00,  9.47it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip86_out_hist: 100%|██████████| 13/13 [00:01<00:00,  9.17it/s]
#
#
#
#
# Converting video in trip48_out_hist:   4%|▍         | 7/163 [00:00<00:14, 11.06it/s]
#
#
#
#
#
#
#
#
# Converting video in trip38_out_hist:   4%|▍         | 14/329 [00:01<00:31, 10.08it/s]
#
#
#
#
# Converting video in trip103_out_hist: 100%|██████████| 6/6 [00:00<00:00,  9.81it/s]
#
#
#
#
# Converting video in trip101_out_hist: 100%|██████████| 7/7 [00:00<00:00, 10.72it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in trip89_out_hist: 100%|██████████| 16/16 [00:01<00:00, 10.27it/s]
#
#
#
#
#
#
# Converting video in trip90_out_hist: 100%|██████████| 10/10 [00:00<00:00, 10.14it/s]
#
#
#
#
#
# Converting video in trip84_out_hist:   4%|▍         | 8/181 [00:00<00:17,  9.92it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip42_out_hist:   4%|▍         | 14/319 [00:01<00:33,  9.16it/s]
#
#
#
#
#
# Converting video in trip63_out_hist:   5%|▍         | 8/173 [00:00<00:15, 10.49it/s]
#
#
#
#
#
# Converting video in trip1_out_hist: 100%|██████████| 9/9 [00:00<00:00, 12.92it/s]
#
#
#
#
#
#
# Converting video in trip10_out_hist:   5%|▍         | 6/127 [00:00<00:13,  8.83it/s]
#
#
#
#
#
#
#
#
#
# Converting video in trip12_out_hist:   5%|▍         | 8/171 [00:00<00:19,  8.23it/s]
#
#
#
#
#
#
#
# Converting video in trip28_out_hist:   4%|▍         | 8/181 [00:00<00:18,  9.12it/s]
#
#
#
#
#
#
#
#
# Converting video in trip44_out_hist:   4%|▍         | 12/273 [00:01<00:26,  9.89it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip105_out_hist: 100%|██████████| 16/16 [00:01<00:00,  9.57it/s]
#
#
#
#
#
#
# Converting video in trip100_out_hist: 100%|██████████| 11/11 [00:01<00:00, 10.32it/s]
#
#
#
#
#
#
#
#
# Converting video in trip72_out_hist:   4%|▍         | 14/327 [00:01<00:29, 10.56it/s]
#
#
#
#
#
# Converting video in trip7_out_hist: 100%|██████████| 9/9 [00:00<00:00, 17.44it/s]
#
#
#
#
#
# Converting video in trip30_out_hist:   5%|▍         | 7/151 [00:00<00:15,  9.45it/s]
#
#
#
#
#
#
#
#
#
# Converting video in trip83_out_hist:   4%|▍         | 12/275 [00:01<00:28,  9.18it/s]
#
#
#
#
#
# Converting video in trip79_out_hist:   4%|▍         | 7/161 [00:00<00:13, 11.47it/s]
#
#
#
#
# Converting video in trip31_out_hist:   5%|▍         | 6/125 [00:00<00:12,  9.86it/s]
#
#
#
#
#
#
# Converting video in trip67_out_hist:   4%|▍         | 9/215 [00:00<00:22,  9.26it/s]
#
#
#
#
#
# Converting video in trip9_out_hist: 100%|██████████| 9/9 [00:00<00:00, 16.75it/s]
#
#
#
#
#
# Converting video in trip15_out_hist:   5%|▍         | 9/193 [00:00<00:16, 10.89it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in trip97_out_hist: 100%|██████████| 10/10 [00:01<00:00,  8.16it/s]
#
#
#
#
#
#
#
#
#
# Converting video in trip62_out_hist:   4%|▍         | 10/227 [00:01<00:29,  7.39it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in trip91_out_hist: 100%|██████████| 14/14 [00:01<00:00,  9.63it/s]
#
#
#
# Converting video in trip88_out_hist: 100%|██████████| 5/5 [00:00<00:00,  9.86it/s]
#
#
#
#
#
#
# Converting video in trip93_out_hist: 100%|██████████| 5/5 [00:00<00:00,  8.10it/s]
#
#
#
#
# Converting video in trip23_out_hist:   4%|▍         | 7/159 [00:00<00:13, 11.15it/s]
#
#
#
#
#
#
# Converting video in trip56_out_hist:   5%|▍         | 11/241 [00:01<00:21, 10.81it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip65_out_hist:   4%|▍         | 25/595 [00:02<00:52, 10.92it/s]
#
#
#
#
#
#
#
# Converting video in trip25_out_hist:   4%|▍         | 12/275 [00:01<00:26,  9.81it/s]
#
#
#
#
#
# Converting video in trip2_out_hist: 100%|██████████| 9/9 [00:00<00:00, 16.79it/s]
#
#
#
#
#
#
#
# Converting video in trip34_out_hist:   4%|▍         | 11/257 [00:00<00:21, 11.19it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip98_out_hist: 100%|██████████| 14/14 [00:01<00:00,  9.55it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip73_out_hist:   4%|▍         | 18/413 [00:01<00:41,  9.60it/s]
#
#
#
#
#
#
# Converting video in trip11_out_hist:   4%|▍         | 10/223 [00:00<00:20, 10.62it/s]
#
#
#
#
#
#
#
#
#
# Converting video in trip50_out_hist:   5%|▍         | 9/199 [00:01<00:23,  7.98it/s]
#
#
#
#
#
# Converting video in trip68_out_hist:   4%|▍         | 5/119 [00:00<00:14,  7.92it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip94_out_hist: 100%|██████████| 10/10 [00:01<00:00,  7.49it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip27_out_hist:   4%|▍         | 13/297 [00:01<00:33,  8.56it/s]
#
#
#
#
# Converting video in trip64_out_hist:   4%|▍         | 4/95 [00:00<00:10,  8.34it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip104_out_hist: 100%|██████████| 10/10 [00:01<00:00,  7.84it/s]
#
#
#
#
#
# Converting video in trip4_out_hist: 100%|██████████| 9/9 [00:00<00:00, 13.79it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in trip45_out_hist:   4%|▍         | 9/207 [00:01<00:25,  7.77it/s]
#
#
#
#
#
#
#
# Converting video in trip96_out_hist: 100%|██████████| 12/12 [00:01<00:00, 10.33it/s]
#
#
#
#
#
#
#
# Converting video in trip108_out_hist: 100%|██████████| 12/12 [00:01<00:00, 11.14it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip41_out_hist:   4%|▍         | 13/309 [00:01<00:34,  8.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip111_out_hist: 100%|██████████| 15/15 [00:01<00:00,  7.93it/s]
#
#
#
#
#
#
#
# Converting video in trip5_out_hist: 100%|██████████| 9/9 [00:00<00:00, 10.95it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip29_out_hist:   4%|▍         | 10/227 [00:01<00:28,  7.68it/s]
#
#
#
#
#
# Converting video in trip59_out_hist:   5%|▍         | 6/127 [00:00<00:13,  8.95it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in trip81_out_hist:   4%|▍         | 10/229 [00:01<00:25,  8.55it/s]
#
#
#
#
#
# Converting video in trip3_out_hist: 100%|██████████| 9/9 [00:00<00:00, 16.95it/s]
#
#
#
#
#
#
# Converting video in trip33_out_hist:   4%|▍         | 8/181 [00:00<00:18,  9.32it/s]
#
#
#
#
# Converting video in trip75_out_hist:   4%|▍         | 7/159 [00:00<00:14, 10.63it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in trip20_out_hist:   4%|▍         | 13/293 [00:01<00:29,  9.44it/s]
#
#
#
#
#
#
#
# Converting video in trip71_out_hist:   4%|▍         | 12/267 [00:01<00:22, 11.43it/s]
#
#
#
#
# Converting video in trip32_out_hist:   5%|▍         | 7/149 [00:00<00:14,  9.67it/s]
#
#
#
#
#
#
#
#
#
# Converting video in trip40_out_hist:   5%|▍         | 11/243 [00:01<00:26,  8.80it/s]
#
#
#
#
# Converting video in trip66_out_hist:   4%|▍         | 7/163 [00:00<00:14, 10.46it/s]
#
#
#
#
#
#
#
#
# Converting video in trip36_out_hist:   4%|▍         | 11/249 [00:01<00:25,  9.43it/s]
#
#
#
#
#
#
#
#
# Converting video in trip16_out_hist:   4%|▍         | 7/159 [00:00<00:17,  8.63it/s]
#
#
#
#
#
# Converting video in trip18_out_hist:   5%|▍         | 8/171 [00:00<00:16, 10.11it/s]
#
#
#
#
#
#
#
#
# Converting video in trip85_out_hist: 100%|██████████| 15/15 [00:01<00:00, 10.37it/s]
#
#
#
#
#
# Converting video in trip77_out_hist:   5%|▍         | 8/175 [00:00<00:16, 10.03it/s]
# Converting videos in road_view: 100%|██████████| 224/224 [01:53<00:00,  1.97it/s]
# Processing folders:  19%|█▉        | 4/21 [05:47<25:42, 90.72s/it]
#
#
#
#
#
#
#
#
# Converting video in sample107: 100%|██████████| 16/16 [00:01<00:00, 15.47it/s]
#
#
#
#
#
#
#
# Converting video in sample28: 100%|██████████| 13/13 [00:00<00:00, 15.20it/s]
#
#
#
#
#
#
# Converting video in sample17: 100%|██████████| 11/11 [00:00<00:00, 15.88it/s]
#
#
#
#
#
#
#
# Converting video in sample66: 100%|██████████| 12/12 [00:00<00:00, 16.98it/s]
#
#
#
#
#
#
#
#
# Converting video in sample70: 100%|██████████| 14/14 [00:00<00:00, 16.48it/s]
#
#
#
#
#
#
#
#
# Converting video in sample53: 100%|██████████| 14/14 [00:00<00:00, 15.82it/s]
#
#
#
#
#
#
# Converting video in sample101: 100%|██████████| 11/11 [00:00<00:00, 16.82it/s]
#
#
#
#
#
#
#
#
# Converting video in sample47: 100%|██████████| 14/14 [00:00<00:00, 15.69it/s]
#
#
#
#
# Converting video in sample57: 100%|██████████| 7/7 [00:00<00:00, 15.55it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample92: 100%|██████████| 18/18 [00:01<00:00, 12.99it/s]
#
#
#
#
#
#
# Converting video in sample7: 100%|██████████| 11/11 [00:00<00:00, 12.81it/s]
#
#
#
#
#
#
#
# Converting video in sample50: 100%|██████████| 13/13 [00:00<00:00, 13.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample105: 100%|██████████| 23/23 [00:01<00:00, 15.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample85: 100%|██████████| 22/22 [00:01<00:00, 14.75it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample11: 100%|██████████| 16/16 [00:00<00:00, 16.46it/s]
#
#
#
#
#
#
# Converting video in sample4: 100%|██████████| 11/11 [00:00<00:00, 16.37it/s]
#
#
#
#
#
#
#
# Converting video in sample77: 100%|██████████| 12/12 [00:00<00:00, 16.97it/s]
#
#
#
#
#
#
# Converting video in sample97: 100%|██████████| 15/15 [00:00<00:00, 20.34it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample95: 100%|██████████| 19/19 [00:01<00:00, 18.69it/s]
#
#
#
#
#
# Converting video in sample6: 100%|██████████| 12/12 [00:00<00:00, 19.75it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample106: 100%|██████████| 23/23 [00:01<00:00, 18.49it/s]
#
#
#
#
# Converting video in sample5: 100%|██████████| 10/10 [00:00<00:00, 19.06it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample39: 100%|██████████| 19/19 [00:00<00:00, 19.00it/s]
#
#
#
#
#
#
# Converting video in sample51: 100%|██████████| 14/14 [00:00<00:00, 18.29it/s]
#
#
#
#
#
# Converting video in sample59: 100%|██████████| 10/10 [00:00<00:00, 19.62it/s]
#
#
#
#
# Converting video in sample93: 100%|██████████| 9/9 [00:00<00:00, 19.99it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample91: 100%|██████████| 20/20 [00:01<00:00, 17.60it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample38: 100%|██████████| 21/21 [00:01<00:00, 15.18it/s]
#
#
#
#
#
#
#
#
# Converting video in sample81: 100%|██████████| 15/15 [00:01<00:00, 12.83it/s]
#
#
#
#
#
#
#
#
# Converting video in sample67: 100%|██████████| 15/15 [00:01<00:00, 12.73it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample110: 100%|██████████| 27/27 [00:01<00:00, 13.63it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample22: 100%|██████████| 16/16 [00:01<00:00, 13.20it/s]
#
#
#
#
#
#
#
#
# Converting video in sample15: 100%|██████████| 14/14 [00:00<00:00, 14.81it/s]
#
#
#
#
#
#
#
# Converting video in sample48: 100%|██████████| 12/12 [00:00<00:00, 15.62it/s]
#
#
#
#
#
#
#
#
# Converting video in sample99: 100%|██████████| 14/14 [00:00<00:00, 14.49it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample44: 100%|██████████| 18/18 [00:01<00:00, 15.66it/s]
#
#
#
#
#
#
#
#
# Converting video in sample87: 100%|██████████| 15/15 [00:00<00:00, 15.31it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample108: 100%|██████████| 18/18 [00:01<00:00, 15.18it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample49: 100%|██████████| 20/20 [00:01<00:00, 16.87it/s]
#
#
#
#
#
#
#
# Converting video in sample37: 100%|██████████| 13/13 [00:00<00:00, 16.96it/s]
#
#
#
#
# Converting video in sample68: 100%|██████████| 9/9 [00:00<00:00, 18.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample65: 100%|██████████| 36/36 [00:02<00:00, 17.89it/s]
#
#
#
#
#
#
#
# Converting video in sample46: 100%|██████████| 12/12 [00:00<00:00, 16.97it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample89: 100%|██████████| 23/23 [00:01<00:00, 17.50it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample20: 100%|██████████| 20/20 [00:01<00:00, 17.35it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample21: 100%|██████████| 18/18 [00:01<00:00, 13.14it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample26: 100%|██████████| 19/19 [00:01<00:00, 14.11it/s]
#
#
#
#
#
#
#
# Converting video in sample82: 100%|██████████| 12/12 [00:00<00:00, 14.40it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample96: 100%|██████████| 18/18 [00:01<00:00, 15.03it/s]
#
#
#
#
#
#
# Converting video in sample60: 100%|██████████| 10/10 [00:00<00:00, 12.81it/s]
#
#
#
#
#
#
#
# Converting video in sample30: 100%|██████████| 12/12 [00:00<00:00, 13.74it/s]
#
#
#
#
#
#
#
# Converting video in sample8: 100%|██████████| 12/12 [00:00<00:00, 14.21it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample98: 100%|██████████| 20/20 [00:01<00:00, 14.36it/s]
#
#
#
#
#
#
# Converting video in sample2: 100%|██████████| 11/11 [00:00<00:00, 13.55it/s]
#
#
#
#
#
#
#
# Converting video in sample32: 100%|██████████| 12/12 [00:00<00:00, 13.26it/s]
#
#
#
#
#
# Converting video in sample64: 100%|██████████| 8/8 [00:00<00:00, 13.84it/s]
#
#
#
#
#
#
# Converting video in sample79: 100%|██████████| 11/11 [00:00<00:00, 12.69it/s]
#
#
#
#
#
#
#
# Converting video in sample23: 100%|██████████| 12/12 [00:00<00:00, 16.65it/s]
#
#
#
#
#
#
#
# Converting video in sample12: 100%|██████████| 13/13 [00:00<00:00, 15.11it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample24: 100%|██████████| 18/18 [00:01<00:00, 16.47it/s]
#
#
#
#
# Converting video in sample10: 100%|██████████| 6/6 [00:00<00:00, 16.92it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample54: 100%|██████████| 16/16 [00:00<00:00, 16.59it/s]
#
#
#
#
#
#
# Converting video in sample13: 100%|██████████| 12/12 [00:00<00:00, 18.10it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample100: 100%|██████████| 17/17 [00:00<00:00, 17.56it/s]
#
#
#
#
#
# Converting video in sample103: 100%|██████████| 10/10 [00:00<00:00, 19.57it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample29: 100%|██████████| 16/16 [00:00<00:00, 18.17it/s]
#
#
#
#
#
# Converting video in sample76: 100%|██████████| 9/9 [00:00<00:00, 16.06it/s]
#
#
#
#
#
# Converting video in sample19: 100%|██████████| 8/8 [00:00<00:00, 14.71it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample25: 100%|██████████| 19/19 [00:01<00:00, 15.86it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample72: 100%|██████████| 21/21 [00:01<00:00, 18.51it/s]
#
#
#
#
#
#
#
#
# Converting video in sample62: 100%|██████████| 15/15 [00:00<00:00, 16.69it/s]
#
#
#
#
#
#
#
#
# Converting video in sample80: 100%|██████████| 15/15 [00:00<00:00, 17.34it/s]
#
#
#
#
#
#
# Converting video in sample112: 100%|██████████| 11/11 [00:00<00:00, 17.89it/s]
#
#
#
#
#
#
#
# Converting video in sample102: 100%|██████████| 13/13 [00:00<00:00, 17.22it/s]
#
#
#
#
#
#
#
# Converting video in sample55: 100%|██████████| 13/13 [00:00<00:00, 18.31it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample86: 100%|██████████| 18/18 [00:01<00:00, 17.94it/s]
#
#
#
#
#
#
#
# Converting video in sample33: 100%|██████████| 13/13 [00:00<00:00, 16.76it/s]
#
#
#
#
# Converting video in sample88: 100%|██████████| 7/7 [00:00<00:00, 18.43it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample56: 100%|██████████| 16/16 [00:00<00:00, 17.47it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample27: 100%|██████████| 20/20 [00:01<00:00, 17.06it/s]
#
#
#
#
#
#
# Converting video in sample14: 100%|██████████| 11/11 [00:00<00:00, 17.10it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample90: 100%|██████████| 16/16 [00:00<00:00, 17.63it/s]
#
#
#
#
#
#
#
#
# Converting video in sample35: 100%|██████████| 15/15 [00:00<00:00, 17.60it/s]
#
#
#
#
#
#
#
# Converting video in sample18: 100%|██████████| 12/12 [00:00<00:00, 16.66it/s]
#
#
#
#
#
#
#
#
# Converting video in sample36: 100%|██████████| 17/17 [00:00<00:00, 18.42it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample73: 100%|██████████| 25/25 [00:01<00:00, 17.50it/s]
#
#
#
#
#
#
# Converting video in sample9: 100%|██████████| 11/11 [00:00<00:00, 16.90it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample71: 100%|██████████| 17/17 [00:00<00:00, 17.62it/s]
#
#
#
#
#
#
# Converting video in sample43: 100%|██████████| 10/10 [00:00<00:00, 18.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample111: 100%|██████████| 23/23 [00:01<00:00, 17.89it/s]
#
#
#
#
#
#
# Converting video in sample16: 100%|██████████| 12/12 [00:00<00:00, 17.81it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample42: 100%|██████████| 19/19 [00:01<00:00, 17.88it/s]
#
#
#
#
#
#
#
# Converting video in sample84: 100%|██████████| 12/12 [00:00<00:00, 17.27it/s]
#
#
#
#
#
#
# Converting video in sample63: 100%|██████████| 12/12 [00:00<00:00, 17.63it/s]
#
#
#
#
#
#
#
# Converting video in sample104: 100%|██████████| 15/15 [00:00<00:00, 18.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample52: 100%|██████████| 26/26 [00:01<00:00, 14.56it/s]
#
#
#
#
#
#
#
# Converting video in sample74: 100%|██████████| 13/13 [00:01<00:00, 12.16it/s]
#
#
#
#
#
#
# Converting video in sample3: 100%|██████████| 11/11 [00:00<00:00, 13.55it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample58: 100%|██████████| 15/15 [00:01<00:00, 12.81it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample41: 100%|██████████| 21/21 [00:01<00:00, 12.59it/s]
#
#
#
#
#
#
#
#
# Converting video in sample94: 100%|██████████| 14/14 [00:01<00:00, 13.30it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample109: 100%|██████████| 25/25 [00:01<00:00, 13.43it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample78: 100%|██████████| 18/18 [00:01<00:00, 12.74it/s]
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample65: 100%|██████████| 36/36 [00:02<00:00, 17.01it/s]
#
#
#
#
#
#
# Converting video in sample46: 100%|██████████| 12/12 [00:00<00:00, 18.05it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample89: 100%|██████████| 24/24 [00:01<00:00, 17.74it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample20: 100%|██████████| 20/20 [00:01<00:00, 16.44it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample21: 100%|██████████| 17/17 [00:01<00:00, 16.33it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample26: 100%|██████████| 18/18 [00:01<00:00, 17.18it/s]
#
#
#
#
#
#
# Converting video in sample82: 100%|██████████| 11/11 [00:00<00:00, 17.65it/s]
#
#
#
#
#
# Converting video in sample96: 100%|██████████| 11/11 [00:00<00:00, 18.63it/s]
#
#
#
#
#
# Converting video in sample60: 100%|██████████| 10/10 [00:00<00:00, 17.97it/s]
#
#
#
#
#
#
# Converting video in sample30: 100%|██████████| 11/11 [00:00<00:00, 17.42it/s]
#
#
#
#
#
#
# Converting video in sample8: 100%|██████████| 12/12 [00:00<00:00, 17.44it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample98: 100%|██████████| 20/20 [00:01<00:00, 14.50it/s]
#
#
#
#
#
#
#
# Converting video in sample2: 100%|██████████| 12/12 [00:00<00:00, 14.82it/s]
#
#
#
#
#
#
# Converting video in sample32: 100%|██████████| 11/11 [00:00<00:00, 15.68it/s]
#
#
#
#
#
# Converting video in sample64: 100%|██████████| 8/8 [00:00<00:00, 15.17it/s]
#
#
#
#
#
#
#
# Converting video in sample79: 100%|██████████| 12/12 [00:00<00:00, 14.90it/s]
#
#
#
#
#
#
#
# Converting video in sample23: 100%|██████████| 12/12 [00:00<00:00, 15.84it/s]
#
#
#
#
#
#
#
# Converting video in sample12: 100%|██████████| 13/13 [00:00<00:00, 15.10it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample24: 100%|██████████| 18/18 [00:01<00:00, 17.28it/s]
#
#
#
#
# Converting video in sample10: 100%|██████████| 7/7 [00:00<00:00, 16.66it/s]
#
#
#
#
#
#
#
# Converting video in sample54: 100%|██████████| 15/15 [00:00<00:00, 18.41it/s]
#
#
#
#
#
#
#
# Converting video in sample13: 100%|██████████| 13/13 [00:00<00:00, 14.52it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample100: 100%|██████████| 16/16 [00:01<00:00, 14.76it/s]
#
#
#
#
#
#
# Converting video in sample103: 100%|██████████| 10/10 [00:00<00:00, 15.03it/s]
#
#
#
#
#
#
#
#
# Converting video in sample29: 100%|██████████| 15/15 [00:00<00:00, 15.01it/s]
#
#
#
# Converting video in sample76: 100%|██████████| 5/5 [00:00<00:00, 13.06it/s]
#
#
#
#
#
# Converting video in sample19: 100%|██████████| 9/9 [00:00<00:00, 14.83it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample25: 100%|██████████| 19/19 [00:01<00:00, 16.20it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample72: 100%|██████████| 20/20 [00:01<00:00, 16.53it/s]
#
#
#
#
#
#
#
#
# Converting video in sample62: 100%|██████████| 15/15 [00:00<00:00, 17.26it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample80: 100%|██████████| 16/16 [00:00<00:00, 17.17it/s]
#
#
# Converting video in sample112: 100%|██████████| 3/3 [00:00<00:00, 14.73it/s]
#
#
#
#
#
#
#
# Converting video in sample102: 100%|██████████| 13/13 [00:00<00:00, 16.34it/s]
#
#
#
#
#
#
#
# Converting video in sample55: 100%|██████████| 13/13 [00:00<00:00, 16.35it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample86: 100%|██████████| 18/18 [00:01<00:00, 17.68it/s]
#
#
#
#
#
#
#
# Converting video in sample33: 100%|██████████| 12/12 [00:00<00:00, 15.48it/s]
#
#
#
#
#
# Converting video in sample88: 100%|██████████| 9/9 [00:00<00:00, 13.96it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample56: 100%|██████████| 16/16 [00:01<00:00, 15.61it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample27: 100%|██████████| 19/19 [00:01<00:00, 14.90it/s]
#
#
#
#
#
#
#
# Converting video in sample14: 100%|██████████| 12/12 [00:00<00:00, 14.69it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample90: 100%|██████████| 16/16 [00:01<00:00, 15.78it/s]
#
#
#
#
#
#
#
#
# Converting video in sample35: 100%|██████████| 14/14 [00:00<00:00, 15.18it/s]
#
#
#
#
#
#
#
# Converting video in sample18: 100%|██████████| 13/13 [00:00<00:00, 15.22it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample36: 100%|██████████| 16/16 [00:01<00:00, 13.84it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample73: 100%|██████████| 23/23 [00:01<00:00, 15.74it/s]
#
#
#
#
#
#
#
# Converting video in sample9: 100%|██████████| 12/12 [00:00<00:00, 14.43it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample71: 100%|██████████| 17/17 [00:01<00:00, 15.26it/s]
#
#
#
#
#
#
# Converting video in sample43: 100%|██████████| 10/10 [00:00<00:00, 14.69it/s]
#
#
#
#
#
#
#
#
# Converting video in sample111: 100%|██████████| 14/14 [00:01<00:00, 13.99it/s]
#
#
#
#
#
#
#
# Converting video in sample16: 100%|██████████| 12/12 [00:00<00:00, 15.43it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample42: 100%|██████████| 20/20 [00:01<00:00, 16.83it/s]
#
#
#
#
#
#
#
# Converting video in sample84: 100%|██████████| 13/13 [00:00<00:00, 17.77it/s]
#
#
#
#
#
#
#
# Converting video in sample63: 100%|██████████| 13/13 [00:00<00:00, 16.93it/s]
#
#
#
#
#
#
#
#
# Converting video in sample104: 100%|██████████| 16/16 [00:00<00:00, 16.37it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample52: 100%|██████████| 25/25 [00:01<00:00, 16.51it/s]
#
#
#
#
#
#
# Converting video in sample74: 100%|██████████| 13/13 [00:00<00:00, 14.60it/s]
#
#
#
#
#
#
#
# Converting video in sample3: 100%|██████████| 12/12 [00:00<00:00, 14.60it/s]
#
#
#
#
#
#
#
#
# Converting video in sample58: 100%|██████████| 15/15 [00:00<00:00, 15.64it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample41: 100%|██████████| 19/19 [00:01<00:00, 14.99it/s]
#
#
#
#
#
#
#
#
# Converting video in sample94: 100%|██████████| 15/15 [00:00<00:00, 15.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample109: 100%|██████████| 25/25 [00:01<00:00, 15.02it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample78: 100%|██████████| 16/16 [00:01<00:00, 11.97it/s]
#
#
#
#
#
#
#
#
# Converting video in sample45: 100%|██████████| 14/14 [00:01<00:00, 12.88it/s]
#
#
#
# Converting video in sample75: 100%|██████████| 4/4 [00:00<00:00, 13.76it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample34: 100%|██████████| 17/17 [00:01<00:00, 13.49it/s]
#
#
#
#
#
# Converting video in sample31: 100%|██████████| 9/9 [00:00<00:00, 12.55it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample40: 100%|██████████| 16/16 [00:01<00:00, 12.33it/s]
#
#
#
#
#
#
# Converting video in sample1: 100%|██████████| 11/11 [00:00<00:00, 12.34it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample83: 100%|██████████| 18/18 [00:01<00:00, 15.88it/s]
#
#
#
#
#
# Converting video in sample61: 100%|██████████| 8/8 [00:00<00:00, 15.90it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample69: 100%|██████████| 16/16 [00:01<00:00, 14.95it/s]
# Processing videos for driver14: 100%|██████████| 112/112 [01:46<00:00,  1.05it/s]
# Processing folders:  95%|█████████▌| 20/21 [31:33<01:38, 98.28s/it]
#
#
#
#
#
#
#
#
# Converting video in sample107: 100%|██████████| 17/17 [00:01<00:00, 14.28it/s]
#
#
#
#
#
#
#
#
# Converting video in sample28: 100%|██████████| 15/15 [00:01<00:00, 13.29it/s]
#
#
#
#
#
#
#
# Converting video in sample17: 100%|██████████| 12/12 [00:00<00:00, 13.41it/s]
#
#
#
#
#
#
#
#
# Converting video in sample66: 100%|██████████| 14/14 [00:00<00:00, 14.29it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample70: 100%|██████████| 17/17 [00:01<00:00, 16.31it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample53: 100%|██████████| 16/16 [00:00<00:00, 16.94it/s]
#
#
#
#
#
#
#
# Converting video in sample101: 100%|██████████| 13/13 [00:00<00:00, 17.87it/s]
#
#
#
#
#
#
# Converting video in sample47: 100%|██████████| 11/11 [00:00<00:00, 16.96it/s]
#
#
#
#
#
#
#
#
# Converting video in sample57: 100%|██████████| 15/15 [00:00<00:00, 17.70it/s]
#
#
#
#
# Converting video in sample92: 100%|██████████| 9/9 [00:00<00:00, 17.41it/s]
#
#
#
#
#
#
#
# Converting video in sample7: 100%|██████████| 12/12 [00:00<00:00, 17.36it/s]
#
#
#
#
#
#
#
#
# Converting video in sample50: 100%|██████████| 14/14 [00:00<00:00, 17.80it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample105: 100%|██████████| 22/22 [00:01<00:00, 16.57it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample85: 100%|██████████| 19/19 [00:01<00:00, 17.16it/s]
#
#
#
#
#
#
#
# Converting video in sample11: 100%|██████████| 13/13 [00:00<00:00, 16.19it/s]
#
#
#
#
#
#
#
# Converting video in sample4: 100%|██████████| 12/12 [00:00<00:00, 17.16it/s]
#
#
#
#
#
#
#
#
# Converting video in sample77: 100%|██████████| 17/17 [00:00<00:00, 18.22it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample97: 100%|██████████| 20/20 [00:01<00:00, 17.60it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample95: 100%|██████████| 17/17 [00:01<00:00, 16.42it/s]
#
#
#
#
#
#
# Converting video in sample6: 100%|██████████| 11/11 [00:00<00:00, 15.78it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample106: 100%|██████████| 17/17 [00:01<00:00, 14.47it/s]
#
#
#
#
#
#
#
# Converting video in sample5: 100%|██████████| 12/12 [00:00<00:00, 12.48it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample39: 100%|██████████| 16/16 [00:01<00:00, 12.05it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample51: 100%|██████████| 24/24 [00:01<00:00, 13.61it/s]
#
#
#
#
#
#
# Converting video in sample59: 100%|██████████| 10/10 [00:00<00:00, 14.37it/s]
#
#
#
#
#
#
#
#
# Converting video in sample93: 100%|██████████| 14/14 [00:01<00:00, 13.28it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample91: 100%|██████████| 17/17 [00:01<00:00, 13.84it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample38: 100%|██████████| 17/17 [00:01<00:00, 13.44it/s]
#
#
#
#
#
#
# Converting video in sample81: 100%|██████████| 11/11 [00:00<00:00, 14.65it/s]
#
#
#
#
#
# Converting video in sample67: 100%|██████████| 9/9 [00:00<00:00, 13.21it/s]
#
#
#
#
#
#
#
#
# Converting video in sample110: 100%|██████████| 14/14 [00:01<00:00, 12.41it/s]
#
#
#
#
#
#
# Converting video in sample22: 100%|██████████| 11/11 [00:00<00:00, 14.14it/s]
#
#
#
#
#
#
# Converting video in sample15: 100%|██████████| 11/11 [00:00<00:00, 15.43it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample48: 100%|██████████| 20/20 [00:01<00:00, 13.22it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample99: 100%|██████████| 16/16 [00:01<00:00, 14.41it/s]
#
#
#
#
#
#
#
# Converting video in sample44: 100%|██████████| 13/13 [00:00<00:00, 14.83it/s]
#
#
#
#
#
# Converting video in sample87: 100%|██████████| 8/8 [00:00<00:00, 14.82it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample108: 100%|██████████| 24/24 [00:01<00:00, 15.16it/s]
#
#
#
#
#
#
#
#
# Converting video in sample49: 100%|██████████| 14/14 [00:00<00:00, 16.74it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample37: 100%|██████████| 19/19 [00:01<00:00, 14.95it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample68: 100%|██████████| 16/16 [00:00<00:00, 17.45it/s]
#
#
#
#
#
#
# Converting video in sample65: 100%|██████████| 11/11 [00:00<00:00, 17.67it/s]
#
#
#
#
#
#
#
#
# Converting video in sample46: 100%|██████████| 14/14 [00:00<00:00, 17.30it/s]
#
#
#
#
#
#
#
#
# Converting video in sample89: 100%|██████████| 15/15 [00:00<00:00, 17.16it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample20: 100%|██████████| 18/18 [00:01<00:00, 17.04it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample21: 100%|██████████| 16/16 [00:00<00:00, 17.80it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample26: 100%|██████████| 19/19 [00:01<00:00, 16.27it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample82: 100%|██████████| 17/17 [00:01<00:00, 16.66it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample96: 100%|██████████| 15/15 [00:01<00:00, 13.20it/s]
#
#
#
#
# Converting video in sample60: 100%|██████████| 7/7 [00:00<00:00, 12.22it/s]
#
#
#
#
#
#
# Converting video in sample30: 100%|██████████| 9/9 [00:00<00:00, 13.24it/s]
#
#
#
#
#
#
# Converting video in sample8: 100%|██████████| 11/11 [00:00<00:00, 14.68it/s]
#
#
#
#
#
#
# Converting video in sample98: 100%|██████████| 11/11 [00:00<00:00, 14.05it/s]
#
#
#
#
#
#
# Converting video in sample2: 100%|██████████| 11/11 [00:00<00:00, 17.06it/s]
#
#
#
#
#
#
#
# Converting video in sample32: 100%|██████████| 12/12 [00:00<00:00, 16.42it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample64: 100%|██████████| 35/35 [00:02<00:00, 16.89it/s]
#
#
#
#
#
#
#
# Converting video in sample79: 100%|██████████| 14/14 [00:00<00:00, 16.18it/s]
#
#
#
#
#
#
#
#
# Converting video in sample23: 100%|██████████| 17/17 [00:01<00:00, 14.87it/s]
#
#
#
#
#
#
#
# Converting video in sample12: 100%|██████████| 13/13 [00:00<00:00, 14.29it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample24: 100%|██████████| 18/18 [00:01<00:00, 13.08it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample10: 100%|██████████| 16/16 [00:01<00:00, 14.71it/s]
#
#
#
#
#
#
#
# Converting video in sample54: 100%|██████████| 12/12 [00:00<00:00, 15.13it/s]
#
#
#
#
#
#
# Converting video in sample13: 100%|██████████| 11/11 [00:00<00:00, 15.01it/s]
#
#
#
#
#
#
# Converting video in sample100: 100%|██████████| 11/11 [00:00<00:00, 17.17it/s]
#
#
#
#
#
#
#
#
# Converting video in sample103: 100%|██████████| 15/15 [00:00<00:00, 15.76it/s]
#
#
#
#
#
#
# Converting video in sample29: 100%|██████████| 11/11 [00:00<00:00, 16.48it/s]
#
#
#
#
#
#
#
# Converting video in sample76: 100%|██████████| 12/12 [00:00<00:00, 15.56it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample19: 100%|██████████| 19/19 [00:01<00:00, 16.89it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample25: 100%|██████████| 18/18 [00:01<00:00, 16.70it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample72: 100%|██████████| 25/25 [00:01<00:00, 16.24it/s]
#
#
#
#
#
#
#
# Converting video in sample62: 100%|██████████| 12/12 [00:00<00:00, 16.25it/s]
#
#
#
#
#
#
#
# Converting video in sample80: 100%|██████████| 14/14 [00:00<00:00, 17.61it/s]
#
#
# Converting video in sample112: 100%|██████████| 3/3 [00:00<00:00, 13.96it/s]
#
#
#
#
#
# Converting video in sample102: 100%|██████████| 9/9 [00:00<00:00, 16.77it/s]
#
#
#
#
#
#
#
#
# Converting video in sample55: 100%|██████████| 15/15 [00:00<00:00, 15.91it/s]
#
#
#
#
#
# Converting video in sample86: 100%|██████████| 14/14 [00:00<00:00, 19.60it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample33: 100%|██████████| 17/17 [00:01<00:00, 15.33it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample88: 100%|██████████| 23/23 [00:01<00:00, 16.16it/s]
#
#
#
#
#
# Converting video in sample56: 100%|██████████| 8/8 [00:00<00:00, 16.68it/s]
#
#
#
#
#
#
#
# Converting video in sample27: 100%|██████████| 12/12 [00:00<00:00, 15.23it/s]
#
#
#
#
#
#
#
# Converting video in sample14: 100%|██████████| 13/13 [00:01<00:00, 12.65it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample90: 100%|██████████| 19/19 [00:01<00:00, 14.11it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample35: 100%|██████████| 16/16 [00:01<00:00, 14.89it/s]
#
#
#
#
#
# Converting video in sample18: 100%|██████████| 8/8 [00:00<00:00, 15.63it/s]
#
#
#
#
#
#
#
# Converting video in sample36: 100%|██████████| 12/12 [00:00<00:00, 15.49it/s]
#
#
#
#
#
#
#
# Converting video in sample73: 100%|██████████| 13/13 [00:00<00:00, 13.96it/s]
#
#
#
#
#
# Converting video in sample9: 100%|██████████| 9/9 [00:00<00:00, 15.19it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample71: 100%|██████████| 19/19 [00:01<00:00, 15.15it/s]
#
#
#
#
#
#
#
#
#
# Converting video in sample43: 100%|██████████| 16/16 [00:01<00:00, 14.65it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample111: 100%|██████████| 22/22 [00:01<00:00, 15.03it/s]
#
#
#
#
#
#
# Converting video in sample16: 100%|██████████| 10/10 [00:00<00:00, 16.18it/s]
#
#
#
#
#
#
# Converting video in sample42: 100%|██████████| 10/10 [00:00<00:00, 16.45it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample84: 100%|██████████| 22/22 [00:01<00:00, 17.15it/s]
#
#
#
#
#
# Converting video in sample63: 100%|██████████| 8/8 [00:00<00:00, 15.73it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample104: 100%|██████████| 23/23 [00:01<00:00, 16.13it/s]
#
#
#
#
#
#
#
#
# Converting video in sample52: 100%|██████████| 14/14 [00:00<00:00, 16.59it/s]
#
#
#
#
#
#
# Converting video in sample74: 100%|██████████| 11/11 [00:00<00:00, 16.05it/s]
#
#
#
#
#
#
#
# Converting video in sample3: 100%|██████████| 12/12 [00:00<00:00, 16.91it/s]
#
#
#
#
#
# Converting video in sample58: 100%|██████████| 9/9 [00:00<00:00, 16.21it/s]
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample41: 100%|██████████| 20/20 [00:01<00:00, 15.34it/s]
#
#
#
#
#
# Converting video in sample94: 100%|██████████| 9/9 [00:00<00:00, 14.54it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Converting video in sample109: 100%|██████████| 26/26 [00:01<00:00, 15.01it/s]
#
#
#
#
#
#
# Converting video in sample78: 100%|██████████| 11/11 [00:00<00:00, 14.98it/s]
#
#
#
#
#
#
#
# Converting video in sample45: 100%|██████████| 12/12 [00:00<00:00, 16.12it/s]
#
#
#
#
#
# Converting video in sample75: 100%|██████████| 9/9 [00:00<00:00, 15.81it/s]
#
#
#
#
#
#
#
#
# Converting video in sample34: 100%|██████████| 14/14 [00:00<00:00, 15.46it/s]
#
#
#
#
#
#
# Converting video in sample31: 100%|██████████| 11/11 [00:00<00:00, 15.45it/s]
#
#
#
#
#
#
#
#
#
#
# Converting video in sample40: 100%|██████████| 19/19 [00:01<00:00, 14.06it/s]
#
#
#
#
#
#
#
# Converting video in sample1: 100%|██████████| 12/12 [00:00<00:00, 16.02it/s]
#
#
#
#
#
#
#
# Converting video in sample83: 100%|██████████| 11/11 [00:00<00:00, 16.63it/s]
#
#
#
#
#
#
#
#
# Converting video in sample61: 100%|██████████| 15/15 [00:00<00:00, 17.19it/s]
#
#
#
#
#
#
#
#
# Converting video in sample69: 100%|██████████| 14/14 [00:00<00:00, 16.77it/s]
# Processing videos for driver11: 100%|██████████| 112/112 [01:45<00:00,  1.06it/s]
# Processing folders: 100%|██████████| 21/21 [33:18<00:00, 95.18s/it]

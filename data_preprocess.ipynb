# %% [markdown]
# ## **Data Preprocessing**

# %%
#!git clone https://github.com/duaisha/DGAZE.git

# %% [markdown]
# Go inside the folder og the datase and run their preprocessing script

# %%
# %cd DGAZE
# !ls
# Out:
# /home/anto/Driving Visual Attention/DGAZE
# codes  README.md  requirements.txt  results

# %% [markdown]
# Install requirements

# %%
# %pip install -r requirements.txt   # -q for quiet no output
# Out:
# Collecting absl-py
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting astor
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: Babel in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (2.9.1)
# Requirement already satisfied: backports.weakref in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (1.0.post1)
# Requirement already satisfied: beautifulsoup4 in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (4.11.1)
# Requirement already satisfied: bleach in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (4.1.0)
# Collecting blinker
#   Using cached blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting boto
#   Using cached boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
# Requirement already satisfied: boto3 in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.21.32)
# Requirement already satisfied: botocore in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.24.32)
# Requirement already satisfied: certifi in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (2021.10.8)
# Requirement already satisfied: chardet in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (4.0.0)
# Collecting checkbox-support
#   Using cached checkbox_support-0.39.0-py3-none-any.whl
# Requirement already satisfied: Click in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (8.0.4)
# Requirement already satisfied: cloudpickle in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (2.0.0)
# Collecting cmake
#   Using cached cmake-3.26.4-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
# Collecting config
#   Using cached config-0.5.1-py2.py3-none-any.whl (20 kB)
# Collecting contextlib2
#   Using cached contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: cycler in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (0.11.0)
# Requirement already satisfied: decorator in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (5.1.1)
# Collecting defer
#   Using cached defer-1.0.4-py3-none-any.whl
# Collecting Django
#   Using cached Django-4.2.3-py3-none-any.whl (8.0 MB)
# Collecting django-extensions
#   Using cached django_extensions-3.2.3-py3-none-any.whl (229 kB)
# Collecting dm-sonnet
#   Using cached dm_sonnet-2.0.1-py3-none-any.whl (268 kB)
# Requirement already satisfied: docutils in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (0.17.1)
# Requirement already satisfied: entrypoints in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (0.4)
# Collecting enum34
#   Using cached enum34-1.1.10-py3-none-any.whl (11 kB)
# Collecting face-alignment
#   Using cached face_alignment-1.4.0-py2.py3-none-any.whl (29 kB)
# Collecting face-recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# Collecting Faker
#   Using cached Faker-18.11.2-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: flake8 in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (3.9.2)
# Requirement already satisfied: future in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (0.18.2)
# Collecting gast
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: gensim in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (4.1.2)
# Collecting google-pasta
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting graphviz
#   Using cached graphviz-0.20.1-py3-none-any.whl (47 kB)
# Collecting guacamole
#   Using cached guacamole-0.9.2-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: h5py in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 50)) (3.6.0)
# Collecting hmmlearn
#   Using cached hmmlearn-0.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (160 kB)
# Collecting html5lib
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Collecting httplib2
#   Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Requirement already satisfied: idna in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 54)) (3.3)
# Collecting imbalanced-learn
#   Using cached imbalanced_learn-0.10.1-py3-none-any.whl (226 kB)
# Collecting imblearn
#   Using cached imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imutils
#   Using cached imutils-0.5.4-py3-none-any.whl
# Requirement already satisfied: ipykernel in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 59)) (6.9.1)
# Requirement already satisfied: ipython in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 60)) (8.2.0)
# Requirement already satisfied: ipython-genutils in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 61)) (0.2.0)
# Requirement already satisfied: ipywidgets in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 62)) (7.6.5)
# Requirement already satisfied: jedi in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 63)) (0.18.1)
# Requirement already satisfied: Jinja2 in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 64)) (2.11.3)
# Requirement already satisfied: jmespath in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 65)) (0.10.0)
# Requirement already satisfied: joblib in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 66)) (1.1.0)
# Requirement already satisfied: jsonschema in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 67)) (4.4.0)
# Requirement already satisfied: jupyter in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 68)) (1.0.0)
# Requirement already satisfied: jupyter-client in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 69)) (6.1.12)
# Requirement already satisfied: jupyter-console in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 70)) (6.4.0)
# Requirement already satisfied: jupyter-core in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 71)) (4.9.2)
# Collecting Keras
#   Using cached keras-2.13.1-py3-none-any.whl (1.7 MB)
# Collecting Keras-Applications
#   Using cached Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Collecting Keras-Preprocessing
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting keras-resnet
#   Using cached keras_resnet-0.2.0-py2.py3-none-any.whl
# Collecting keras-vggface
#   Using cached keras_vggface-0.6-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: kiwisolver in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 77)) (1.3.2)
# Collecting louis
#   Using cached louis-1.3-py3-none-any.whl
# Requirement already satisfied: lxml in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 81)) (4.8.0)
# Collecting Mako
#   Using cached Mako-1.2.4-py3-none-any.whl (78 kB)
# Requirement already satisfied: Markdown in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 84)) (3.3.4)
# Requirement already satisfied: MarkupSafe in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 85)) (2.0.1)
# Requirement already satisfied: matplotlib in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 86)) (3.5.1)
# Requirement already satisfied: mccabe in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 87)) (0.6.1)
# Requirement already satisfied: mistune in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 88)) (0.8.4)
# Collecting mlxtend
#   Using cached mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
# Requirement already satisfied: mock in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 90)) (4.0.3)
# Collecting moviepy
#   Using cached moviepy-1.0.3-py3-none-any.whl
# Requirement already satisfied: nbconvert in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 92)) (6.4.4)
# Requirement already satisfied: nbformat in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 93)) (5.3.0)
# Requirement already satisfied: networkx in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 94)) (2.7.1)
# Requirement already satisfied: nltk in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 96)) (3.7)
# Requirement already satisfied: notebook in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 97)) (6.4.8)
# Requirement already satisfied: numpy in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 98)) (1.21.5)
# Collecting oauthlib
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: olefile in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 100)) (0.46)
# Collecting opencv-python
#   Using cached opencv_python-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
# Collecting padme
#   Using cached padme-1.1.1-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 106)) (1.4.2)
# Collecting pandoc
#   Using cached pandoc-2.3-py3-none-any.whl
# Requirement already satisfied: pandocfilters in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 108)) (1.5.0)
# Requirement already satisfied: parso in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 109)) (0.8.3)
# Requirement already satisfied: patsy in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 110)) (0.5.2)
# Collecting pbr
#   Using cached pbr-5.11.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: pep8 in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 112)) (1.7.1)
# Requirement already satisfied: pexpect in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 113)) (4.8.0)
# Requirement already satisfied: pickleshare in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 114)) (0.7.5)
# Requirement already satisfied: Pillow in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 115)) (9.0.1)
# Collecting plainbox
#   Using cached plainbox-0.38.0-py3-none-any.whl
# Collecting ply
#   Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Requirement already satisfied: protobuf in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 119)) (4.23.3)
# Requirement already satisfied: psutil in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 120)) (5.8.0)
# Requirement already satisfied: ptyprocess in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 121)) (0.7.0)
# Requirement already satisfied: pyasn1 in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 122)) (0.4.8)
# Requirement already satisfied: pycurl in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 125)) (7.44.1)
# Collecting pydot
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pyflakes in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 127)) (2.3.1)
# Requirement already satisfied: Pygments in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 128)) (2.11.2)
# Requirement already satisfied: PyJWT in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 130)) (2.1.0)
# Collecting PyOpenGL
#   Using cached PyOpenGL-3.1.7-py3-none-any.whl (2.4 MB)
# Requirement already satisfied: pyparsing in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 132)) (3.0.4)
# Requirement already satisfied: python-dateutil in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 134)) (2.8.2)
# Collecting python-debian
#   Using cached python_debian-0.1.49-py3-none-any.whl (132 kB)
# Collecting python-resize-image
#   Using cached python_resize_image-1.1.20-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: pytz in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 138)) (2021.3)
# Requirement already satisfied: PyWavelets in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 139)) (1.3.0)
# Requirement already satisfied: pyxdg in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 140)) (0.27)
# Requirement already satisfied: PyYAML in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 141)) (6.0)
# Requirement already satisfied: pyzmq in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 142)) (22.3.0)
# Requirement already satisfied: requests in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 145)) (2.27.1)
# Requirement already satisfied: s3transfer in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 146)) (0.5.0)
# Requirement already satisfied: scikit-image in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 147)) (0.19.2)
# Requirement already satisfied: scikit-learn in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 148)) (1.0.2)
# Collecting scikit-video
#   Using cached scikit_video-1.1.11-py2.py3-none-any.whl (2.3 MB)
# Requirement already satisfied: scipy in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 150)) (1.7.3)
# Requirement already satisfied: seaborn in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 152)) (0.11.2)
# Requirement already satisfied: Send2Trash in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 154)) (1.8.0)
# Collecting simplegeneric
#   Using cached simplegeneric-0.8.1-py3-none-any.whl
# Collecting singledispatch
#   Using cached singledispatch-4.0.0-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: six in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 158)) (1.16.0)
# Collecting sk-video
#   Using cached sk_video-1.1.10-py2.py3-none-any.whl (2.3 MB)
# Requirement already satisfied: smart-open in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 160)) (5.1.0)
# Requirement already satisfied: statsmodels in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 162)) (0.13.2)
# Requirement already satisfied: tabulate in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 164)) (0.8.9)
# Collecting tensorboard
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# Collecting tensorflow-estimator
#   Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
# Collecting tensorflow-probability
#   Using cached tensorflow_probability-0.20.1-py2.py3-none-any.whl (6.9 MB)
# Collecting termcolor
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: terminado in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 170)) (0.13.1)
# Requirement already satisfied: testpath in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 171)) (0.5.0)
# Requirement already satisfied: text-unidecode in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 172)) (1.3)
# Collecting Theano
#   Using cached Theano-1.0.5-py3-none-any.whl
# Collecting torch
#   Using cached torch-2.0.1-cp39-cp39-manylinux1_x86_64.whl (619.9 MB)
# Collecting torchsummary
#   Using cached torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Collecting torchvision
#   Using cached torchvision-0.15.2-cp39-cp39-manylinux1_x86_64.whl (6.0 MB)
# Requirement already satisfied: tqdm in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 178)) (4.64.0)
# Requirement already satisfied: urllib3 in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 196)) (1.26.9)
# Requirement already satisfied: videosequence in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 199)) (1.1.0)
# Requirement already satisfied: virtualenv in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 200)) (15.0.1)
# Requirement already satisfied: wcwidth in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 201)) (0.2.5)
# Requirement already satisfied: webencodings in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 202)) (0.5.1)
# Requirement already satisfied: Werkzeug in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 203)) (2.0.3)
# Requirement already satisfied: widgetsnbextension in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 204)) (3.5.2)
# Requirement already satisfied: wrapt in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 205)) (1.12.1)
# Requirement already satisfied: xdg in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 206)) (4.0.1)
# Requirement already satisfied: XlsxWriter in /home/anto/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 209)) (3.0.3)
# Requirement already satisfied: soupsieve>1.2 in /home/anto/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->-r requirements.txt (line 6)) (2.3.1)
# Requirement already satisfied: packaging in /home/anto/anaconda3/lib/python3.9/site-packages (from bleach->-r requirements.txt (line 7)) (21.3)
# Collecting requests-unixsocket>=0.1.2
#   Using cached requests_unixsocket-0.3.0-py2.py3-none-any.whl (11 kB)
# Collecting sqlparse>=0.3.1
#   Using cached sqlparse-0.4.4-py3-none-any.whl (41 kB)
# Collecting asgiref<4,>=3.6.0
#   Using cached asgiref-3.7.2-py3-none-any.whl (24 kB)
# Collecting dm-tree>=0.1.1
#   Using cached dm_tree-0.1.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (153 kB)
# Requirement already satisfied: numba in /home/anto/anaconda3/lib/python3.9/site-packages (from face-alignment->-r requirements.txt (line 37)) (0.55.1)
# Collecting dlib>=19.7
#   Using cached dlib-19.24.2.tar.gz (11.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pycodestyle<2.8.0,>=2.7.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from flake8->-r requirements.txt (line 42)) (2.7.0)
# Collecting joblib
#   Using cached joblib-1.3.1-py3-none-any.whl (301 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from imbalanced-learn->-r requirements.txt (line 56)) (2.2.0)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 59)) (5.1.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 59)) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/anto/anaconda3/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 59)) (6.1)
# Requirement already satisfied: nest-asyncio in /home/anto/anaconda3/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 59)) (1.5.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from ipykernel->-r requirements.txt (line 59)) (1.5.1)
# Requirement already satisfied: setuptools>=18.5 in /home/anto/anaconda3/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 60)) (61.2.0)
# Requirement already satisfied: backcall in /home/anto/anaconda3/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 60)) (0.2.0)
# Requirement already satisfied: stack-data in /home/anto/anaconda3/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 60)) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 60)) (3.0.20)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from ipywidgets->-r requirements.txt (line 62)) (1.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from jsonschema->-r requirements.txt (line 67)) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from jsonschema->-r requirements.txt (line 67)) (0.18.0)
# Requirement already satisfied: qtconsole in /home/anto/anaconda3/lib/python3.9/site-packages (from jupyter->-r requirements.txt (line 68)) (5.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 86)) (4.25.0)
# Collecting decorator
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: imageio<3.0,>=2.5 in /home/anto/anaconda3/lib/python3.9/site-packages (from moviepy->-r requirements.txt (line 91)) (2.9.0)
# Collecting proglog<=1.0.0
#   Using cached proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Collecting imageio-ffmpeg>=0.2.0
#   Using cached imageio_ffmpeg-0.4.8-py3-none-manylinux2010_x86_64.whl (26.9 MB)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from nbconvert->-r requirements.txt (line 92)) (0.5.13)
# Requirement already satisfied: defusedxml in /home/anto/anaconda3/lib/python3.9/site-packages (from nbconvert->-r requirements.txt (line 92)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/anto/anaconda3/lib/python3.9/site-packages (from nbconvert->-r requirements.txt (line 92)) (0.1.2)
# Requirement already satisfied: fastjsonschema in /home/anto/anaconda3/lib/python3.9/site-packages (from nbformat->-r requirements.txt (line 93)) (2.15.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/anto/anaconda3/lib/python3.9/site-packages (from nltk->-r requirements.txt (line 96)) (2022.3.15)
# Requirement already satisfied: argon2-cffi in /home/anto/anaconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 97)) (21.3.0)
# Requirement already satisfied: prometheus-client in /home/anto/anaconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 97)) (0.13.1)
# Collecting plumbum
#   Using cached plumbum-1.8.2-py3-none-any.whl (127 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from requests->-r requirements.txt (line 145)) (2.0.4)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/anto/anaconda3/lib/python3.9/site-packages (from scikit-image->-r requirements.txt (line 147)) (2021.7.2)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/anto/anaconda3/lib/python3.9/site-packages (from tensorboard->-r requirements.txt (line 165)) (1.33.0)
# Collecting grpcio>=1.48.2
#   Using cached grpcio-1.56.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
# Requirement already satisfied: wheel>=0.26 in /home/anto/anaconda3/lib/python3.9/site-packages (from tensorboard->-r requirements.txt (line 165)) (0.37.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting nvidia-curand-cu11==10.2.10.91
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Collecting triton==2.0.0
#   Using cached triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting nvidia-nvtx-cu11==11.7.91
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Collecting nvidia-nccl-cu11==2.14.3
#   Using cached nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
# Requirement already satisfied: typing-extensions in /home/anto/anaconda3/lib/python3.9/site-packages (from torch->-r requirements.txt (line 174)) (4.1.1)
# Requirement already satisfied: filelock in /home/anto/anaconda3/lib/python3.9/site-packages (from torch->-r requirements.txt (line 174)) (3.6.0)
# Collecting nvidia-cusparse-cu11==11.7.4.91
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Requirement already satisfied: sympy in /home/anto/anaconda3/lib/python3.9/site-packages (from torch->-r requirements.txt (line 174)) (1.10.1)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting lit
#   Using cached lit-16.0.6.tar.gz (153 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/anto/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 165)) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/anto/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 165)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/anto/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 165)) (4.2.2)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.21.0-py2.py3-none-any.whl (182 kB)
# Requirement already satisfied: argon2-cffi-bindings in /home/anto/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook->-r requirements.txt (line 97)) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/anto/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 97)) (1.15.0)
# Requirement already satisfied: pycparser in /home/anto/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 97)) (2.21)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/anto/anaconda3/lib/python3.9/site-packages (from numba->face-alignment->-r requirements.txt (line 37)) (0.38.0)
# Requirement already satisfied: qtpy>=2.0.1 in /home/anto/anaconda3/lib/python3.9/site-packages (from qtconsole->jupyter->-r requirements.txt (line 68)) (2.0.1)
# Requirement already satisfied: executing in /home/anto/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->-r requirements.txt (line 60)) (0.8.3)
# Requirement already satisfied: pure-eval in /home/anto/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->-r requirements.txt (line 60)) (0.2.2)
# Requirement already satisfied: asttokens in /home/anto/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->-r requirements.txt (line 60)) (2.0.5)
# Requirement already satisfied: mpmath>=0.19 in /home/anto/anaconda3/lib/python3.9/site-packages (from sympy->torch->-r requirements.txt (line 174)) (1.2.1)
# Building wheels for collected packages: dlib, lit
#   Building wheel for dlib (PEP 517) ... done
#   Created wheel for dlib: filename=dlib-19.24.2-cp39-cp39-linux_x86_64.whl size=3797540 sha256=a847dfd2f95c8b2e2a54024497061123de9228e47fcab33b4f9bc4cc73d8e735
#   Stored in directory: /home/anto/.cache/pip/wheels/f7/ae/0e/3478eae12f6aed0e3d4880147ca855ba5d58f2e1098c73ab5f
#   Building wheel for lit (PEP 517) ... done
#   Created wheel for lit: filename=lit-16.0.6-py3-none-any.whl size=93582 sha256=9f8aa0eb7aa599b889127dd178530098670ccb1b1afff067035dd046132005c5
#   Stored in directory: /home/anto/.cache/pip/wheels/a5/36/d6/cac2e6fb891889b33a548f2fddb8b4b7726399aaa2ed32b188
# Successfully built dlib lit
# Installing collected packages: decorator, oauthlib, nvidia-cublas-cu11, lit, joblib, cmake, triton, sqlparse, requests-oauthlib, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-cusolver-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cudnn-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, google-auth, asgiref, torch, tensorboard-data-server, requests-unixsocket, proglog, ply, plumbum, padme, opencv-python, Keras, imbalanced-learn, imageio-ffmpeg, guacamole, grpcio, google-auth-oauthlib, gast, face-recognition-models, dm-tree, dlib, Django, absl-py, torchvision, torchsummary, Theano, termcolor, tensorflow-probability, tensorflow-estimator, tensorboard, sk-video, singledispatch, simplegeneric, scikit-video, python-resize-image, python-debian, PyOpenGL, pydot, plainbox, pbr, pandoc, moviepy, mlxtend, Mako, louis, keras-vggface, keras-resnet, Keras-Preprocessing, Keras-Applications, imutils, imblearn, httplib2, html5lib, hmmlearn, graphviz, google-pasta, Faker, face-recognition, face-alignment, enum34, dm-sonnet, django-extensions, defer, contextlib2, config, checkbox-support, boto, blinker, astor
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.33.0
#     Uninstalling google-auth-1.33.0:
#       Successfully uninstalled google-auth-1.33.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-storage 1.31.0 requires google-auth<2.0dev,>=1.11.0, but you have google-auth 2.21.0 which is incompatible.
# google-cloud-core 1.7.1 requires google-auth<2.0dev,>=1.24.0, but you have google-auth 2.21.0 which is incompatible.
# google-api-core 1.25.1 requires google-auth<2.0dev,>=1.21.1, but you have google-auth 2.21.0 which is incompatible.
# Successfully installed Django-4.2.3 Faker-18.11.2 Keras-2.13.1 Keras-Applications-1.0.8 Keras-Preprocessing-1.1.2 Mako-1.2.4 PyOpenGL-3.1.7 Theano-1.0.5 absl-py-1.4.0 asgiref-3.7.2 astor-0.8.1 blinker-1.6.2 boto-2.49.0 checkbox-support-0.39.0 cmake-3.26.4 config-0.5.1 contextlib2-21.6.0 decorator-4.4.2 defer-1.0.4 django-extensions-3.2.3 dlib-19.24.2 dm-sonnet-2.0.1 dm-tree-0.1.8 enum34-1.1.10 face-alignment-1.4.0 face-recognition-1.3.0 face-recognition-models-0.3.0 gast-0.5.4 google-auth-2.21.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 graphviz-0.20.1 grpcio-1.56.0 guacamole-0.9.2 hmmlearn-0.3.0 html5lib-1.1 httplib2-0.22.0 imageio-ffmpeg-0.4.8 imbalanced-learn-0.10.1 imblearn-0.0 imutils-0.5.4 joblib-1.3.1 keras-resnet-0.2.0 keras-vggface-0.6 lit-16.0.6 louis-1.3 mlxtend-0.22.0 moviepy-1.0.3 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 oauthlib-3.2.2 opencv-python-4.8.0.74 padme-1.1.1 pandoc-2.3 pbr-5.11.1 plainbox-0.38.0 plumbum-1.8.2 ply-3.11 proglog-0.1.10 pydot-1.4.2 python-debian-0.1.49 python-resize-image-1.1.20 requests-oauthlib-1.3.1 requests-unixsocket-0.3.0 scikit-video-1.1.11 simplegeneric-0.8.1 singledispatch-4.0.0 sk-video-1.1.10 sqlparse-0.4.4 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tensorflow-estimator-2.13.0 tensorflow-probability-0.20.1 termcolor-2.3.0 torch-2.0.1 torchsummary-1.5.1 torchvision-0.15.2 triton-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Run dataset.py to setup dataset

# %%
# !python codes/dataset.py --path "/home/anto/Driving Visual Attention/data/dataset_download"
# Out:
# Traceback (most recent call last):
#   File "/home/anto/Driving Visual Attention/DGAZE/codes/dataset.py", line 139, in <module>
#     dataset(args.path)
#   File "/home/anto/Driving Visual Attention/DGAZE/codes/dataset.py", line 98, in dataset
#     drivers = os.listdir(path + 'dataset_download/')
# FileNotFoundError: [Errno 2] No such file or directory: '/home/anto/Driving Visual Attention/data/dataset_downloaddataset_download/'

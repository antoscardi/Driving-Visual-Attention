# %% [markdown]
# ## **Data Preprocessing**

# %%
#!git clone https://github.com/duaisha/DGAZE.git

# %% [markdown]
# Go inside the folder og the datase and run their preprocessing script

# %%
# %cd DGAZE
# !ls
# Out:
# /home/anto/Driving Visual Attention/DGAZE
# codes  README.md  requirements.txt  results

# %% [markdown]
# Install requirements

# %%
# %pip install -r requirements.txt  # -q for quiet no output
# Out:
# Processing /home/anto/.cache/pip/wheels/b9/55/4e/29a0012b0d4968cbacb80b149b9f85977799883fb9f65e4086/absl_py-0.7.1-py3-none-any.whl
# ...
#   Using cached astor-0.8.0-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached Babel-2.6.0-py2.py3-none-any.whl (8.1 MB)
# ...
#   Using cached backports.weakref-1.0rc1-py3-none-any.whl (4.3 kB)
# ...
#   Using cached beautifulsoup4-4.4.1-py3-none-any.whl (81 kB)
# ...
#   Using cached bleach-1.5.0-py2.py3-none-any.whl (17 kB)
# Processing /home/anto/.cache/pip/wheels/34/47/2c/e54a502ccbaa51b5961fed7ee0b49f52b694f8f3b0fbc5d4cc/blinker-1.3-py3-none-any.whl
# ...
#   Using cached boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
# ...
#   Using cached boto3-1.9.201-py2.py3-none-any.whl (128 kB)
# ...
#   Using cached botocore-1.12.201-py2.py3-none-any.whl (5.6 MB)
# ...
#   Using cached certifi-2019.6.16-py2.py3-none-any.whl (157 kB)
# ...
# Processing /home/anto/.cache/pip/wheels/3f/a6/4b/d510f0557d394a7aa3d37f1bc1f8dfd40a4ea917bf23e53de9/checkbox_support-0.22-py3-none-any.whl
# ...

# %% [markdown]
# Run dataset.py to setup dataset

# %%
# !python codes/dataset.py --path "/home/anto/Driving Visual Attention/data/dataset_download"
